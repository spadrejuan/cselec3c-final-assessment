# %% [markdown]
# # Machine Learning Notebook for Group 8

# %% [markdown]
# ## Classification Neural Network based on Income Group using PyTorch

# %%
import pandas as pd
import numpy as np
dataset = pd.read_csv('datasets/fies_df_for_ML.csv')

# %%
# Get all expenditure columns as features
expenditure_columns = [
    "family_size",
    "losses_from_entrepreneurial_activities",
    "expenditure_cereal_preparations",
    "expenditure_meat_preparations",
    "expenditure_fish_marine_products",
    "expenditure_dairy_eggs",
    "expenditure_oils_fats",
    "expenditure_fruits_vegetables",
    "expenditure_vegetables",
    "expenditure_sugar_jam_honey",
    "expenditure_other_food",
    "expenditure_fruit_vegetable_juices",
    "expenditure_coffee_cocoa_tea",
    "expenditure_tea",
    "expenditure_cocoa",
    "main_water_supply_second_visit",
    "expenditure_softdrinks",
    "expenditure_non_alcoholic_beverages",
    "expenditure_alcoholic_beverages",
    "expenditure_tobacco",
    "expenditure_other_vegetables",
    "expenditure_services_primary_goods",
    "expenditure_alcohol_production_services",
    "total_food_consumed_home",
    "food_consumed_outside_home",
    "household_food_expenditure",
    "expenditure_clothing_footwear",
    "expenditure_housing_water",
    "actual_house_rent",
    "imputed_house_rental_value",
    "imputed_housing_benefit_rental_value",
    "house_rent_rental_value",
    "expenditure_furnishings_household_maintenance",
    "expenditure_health",
    "expenditure_transportation",
    "expenditure_communication",
    "expenditure_recreation_culture",
    "expenditure_education",
    "expenditure_insurance",
    "expenditure_miscellaneous_goods_services",
    "expenditure_durable_furniture",
    "expenditure_special_family_occasion",
    "other_expenditure",
    "other_disbursements",
    "expenditure_accommodation_services",
    "total_non_food_expenditure",
    "total_household_expenditures",
    "total_household_disbursements",
    "urban_rural",
    'income_group', # include target variable
]

# %%
# Only use expenditure columns
expenditure_dataset = dataset[expenditure_columns]

# %%
# Stratified split to get equal representation of all income statuses:
from sklearn.model_selection import train_test_split

# 70% for training, and 30% for test
train, test = train_test_split(
    expenditure_dataset,
    test_size=0.3,
    stratify=dataset['income_group'],
    random_state=42
)
print(f'Training Set Shape: ', train.shape)
print(f'Test Set Shape: ', test.shape)
# Out:
# Training Set Shape:  (114287, 50)
# Test Set Shape:  (48981, 50)

# %%
# Split the dataset into training, validation, and testing sets
target_column = ['income_group']
X_train, y_train = train.drop(columns=target_column), train['income_group']
X_test, y_test = test.drop(columns=target_column), test['income_group']

# %%
# Scale all data 
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
scaler = StandardScaler()

# For Training
X_train_scaled = scaler.fit_transform(X_train)

# For Testing
X_test_scaled = scaler.transform(X_test)

# Encoding the Target Variable
label_encoder = LabelEncoder()
# For Training
y_train = label_encoder.fit_transform(y_train)

# For Testing
y_test = label_encoder.transform(y_test)

# %%
# Convert to PyTorch Tensors
import torch
X_train_tensor = torch.tensor(X_train_scaled, dtype=torch.float32)
X_test_tensor = torch.tensor(X_test_scaled, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)
y_test_tensor = torch.tensor(y_test, dtype=torch.long)

# %%
from torch.utils.data import TensorDataset, DataLoader
# Define the TensorDataset and DataLoader along with a constant BATCH_SIZE
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

BATCH_SIZE = 32
train_dataloader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %%
# Defining the ANN Architecture
import torch.nn as nn

class FIESANN(nn.Module):
    def __init__(self, input_size, num_classes):
        super().__init__()
        self.fc1 = nn.Linear(input_size, 64)
        self.fc2 = nn.Linear(64, 32)
        self.fc3 = nn.Linear(32, 16)
        self.output_neuron = nn.Linear(16, num_classes)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = torch.relu(self.fc3(x))
        x = self.output_neuron(x)
        return x

# %%
# Custom EarlyStopping function
class EarlyStopping:
    def __init__(self, patience=7, verbose=False, delta=0, path=None):
        """
        Args:
            patience (int): How long to wait after last time the F1 score improved.
                            Default: 7
            verbose (bool): If True, prints a message for each F1 score improvement.
                            Default: False
            delta (float): Minimum change in the monitored quantity to qualify as an improvement.
                            Default: 0
            path (str): Path for saving the model if it improves. If None, stores the state in memory.
        """
        self.patience = patience
        self.verbose = verbose
        self.delta = delta
        self.path = path
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.best_val_score = -np.inf
        self.best_model_state = None

    def __call__(self, val_score, model):
        if not np.isfinite(val_score):
            # Skip NaN or infinite values
            if self.verbose:
                print("Warning: Invalid score (NaN or Inf). Skipping update.")
            return

        if self.best_score is None:
            self.best_score = val_score
            self.save_checkpoint(val_score, model)
        elif val_score > self.best_score + self.delta: # adjust this to < when tracking a metric instead if loss
            self.counter += 1
            if self.verbose:
                print(f"EarlyStopping counter: {self.counter} out of {self.patience}")
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = val_score
            self.save_checkpoint(val_score, model)
            self.counter = 0

    def save_checkpoint(self, val_score, model):
        """Saves model when validation score improves."""
        if self.verbose:
            print(f"Tracked Validation Score improved ({self.best_val_score:.4f} --> {val_score:.4f}). Saving model...")
        if self.path:
            torch.save(model.state_dict(), self.path)
        else:
            self.best_model_state = model.state_dict()
        self.best_val_score = val_score

# %%
# Setting up K-Fold Validation for a more robust evaluation
from sklearn.model_selection import KFold
EPOCHS = 100
k_folds = 5
initial_lr = 0.001

kfold = KFold(n_splits=k_folds, shuffle=True, random_state=42)

# Metrics storage
fold_metrics = {
    "train_loss": [],
    "train_accuracy": [],
    "train_precision": [],
    "train_recall": [],
    "train_f1": [],
}

fold_performance = {
    "train_loss": [],
    "train_accuracy": [],
    "train_precision": [],
    "train_recall": [],
    "train_f1": [],
}

# %%
# Start K-Fold Training
import torch.nn as nn
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.utils.data import Subset
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
for fold, (train_idx, val_idx) in enumerate(kfold.split(X_train)):
    print(f"Fold {fold + 1}/{k_folds}")

    # Split the data into training and validation sets
    train_subset = Subset(train_dataset, train_idx)
    val_subset = Subset(train_dataset, val_idx)
    
    train_loader = DataLoader(train_subset, batch_size=BATCH_SIZE, shuffle=True)
    val_loader = DataLoader(val_subset, batch_size=BATCH_SIZE, shuffle=False)

    # Initialize the model, optimizer and utility methods
    model = FIESANN(input_size=X_train.shape[1], num_classes=dataset['income_group'].nunique())
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.CrossEntropyLoss()
    lr_scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=15)
    early_stopping = EarlyStopping(patience=30, delta=0.00001, path=f'checkpoints/fies_ann_checkpoint_fold{fold+1}.pth', verbose=True)

    best_train_loss = np.inf
    best_train_accuracy = 0.0
    best_train_precision = 0.0
    best_train_recall = 0.0
    best_train_f1 = 0.0

    for epoch in range(EPOCHS):
        # Training phase
        model.train()
        train_loss = 0
        y_train_true = []
        y_train_pred = []
        
        for batch in train_dataloader:
            inputs, labels = batch
            outputs = model(inputs)  # Outputs shape: (batch_size, num_classes)
            
            # Use CrossEntropyLoss for multi-class classification
            loss = criterion(outputs, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            train_loss += loss.item()
            
            # Get predicted class (index of the max logit)
            preds = torch.argmax(outputs, dim=1)
            
            y_train_true.extend(labels.cpu().numpy())
            y_train_pred.extend(preds.cpu().numpy())
        
        train_loss /= len(train_dataloader)
        
        # Calculate metrics (multi-class version)
        train_accuracy = accuracy_score(y_train_true, y_train_pred)
        train_precision = precision_score(y_train_true, y_train_pred, average='macro')
        train_recall = recall_score(y_train_true, y_train_pred, average='macro')
        train_f1 = f1_score(y_train_true, y_train_pred, average='macro')

        fold_metrics["train_loss"].append(np.round(train_loss, 4))
        fold_metrics["train_accuracy"].append(train_accuracy)
        fold_metrics["train_precision"].append(train_precision)
        fold_metrics["train_recall"].append(train_recall)
        fold_metrics["train_f1"].append(train_f1)

        print(f'Epoch [{epoch+1}/{EPOCHS}] with Learning Rate: {lr_scheduler.get_last_lr()} \nLoss: {train_loss:.4f}' +  
            f'\nTrain Accuracy: {train_accuracy:.2%} Train Precision: {train_precision:.2%}, Train Recall: {train_recall:.2%}, Train F1 Score: {train_f1:.2%}\n')
        
        lr_scheduler.step(train_loss)
        early_stopping(train_loss, model)
        if train_accuracy > best_train_accuracy:
            best_train_loss = train_loss
            best_train_accuracy = train_accuracy
            best_train_precision = train_precision
            best_train_recall = train_recall
            best_train_f1 = train_f1
        if early_stopping.early_stop:
            print("Early stopping triggered")
            break

    fold_performance["train_loss"].append(np.round(best_train_loss, 4))
    fold_performance["train_accuracy"].append(best_train_accuracy)
    fold_performance["train_precision"].append(best_train_precision)
    fold_performance["train_recall"].append(best_train_recall)
    fold_performance["train_f1"].append(best_train_f1)
    print(f"\nFold {fold + 1} Performance:\n")
    print(f"Best Train Loss: {best_train_loss:.4f}")
    print(f"Best Train Accuracy: {best_train_accuracy:.2%}")
    print(f"Best Train Precision: {best_train_precision:.2%}")
    print(f"Best Train Recall: {best_train_recall:.2%}")
    print(f"Best Train F1 Score: {best_train_f1:.2%}")
# Out:
# Fold 1/10
# Epoch [1/100] with Learning Rate: [0.001]
# Loss: 0.6241
# Train Accuracy: 74.73% Train Precision: 64.04%, Train Recall: 53.61%, Train F1 Score: 56.72%
#
# Tracked Validation Score improved (-inf --> 0.6241). Saving model...
# Epoch [2/100] with Learning Rate: [0.001]
# Loss: 0.5595
# Train Accuracy: 76.69% Train Precision: 66.19%, Train Recall: 60.93%, Train F1 Score: 63.04%
#
# Tracked Validation Score improved (0.6241 --> 0.5595). Saving model...
# Epoch [3/100] with Learning Rate: [0.001]
# Loss: 0.5528
# Train Accuracy: 76.99% Train Precision: 67.42%, Train Recall: 62.33%, Train F1 Score: 64.52%
#
# Tracked Validation Score improved (0.5595 --> 0.5528). Saving model...
# Epoch [4/100] with Learning Rate: [0.001]
# Loss: 0.5490
# Train Accuracy: 77.13% Train Precision: 68.98%, Train Recall: 63.68%, Train F1 Score: 65.76%
#
# Tracked Validation Score improved (0.5528 --> 0.5490). Saving model...
# Epoch [5/100] with Learning Rate: [0.001]
# Loss: 0.5446
# Train Accuracy: 77.22% Train Precision: 69.56%, Train Recall: 63.73%, Train F1 Score: 66.12%
#
# Tracked Validation Score improved (0.5490 --> 0.5446). Saving model...
# Epoch [6/100] with Learning Rate: [0.001]
# Loss: 0.5418
# Train Accuracy: 77.38% Train Precision: 69.38%, Train Recall: 63.13%, Train F1 Score: 65.71%
#
# Tracked Validation Score improved (0.5446 --> 0.5418). Saving model...
# Epoch [7/100] with Learning Rate: [0.001]
# Loss: 0.5402
# Train Accuracy: 77.34% Train Precision: 70.60%, Train Recall: 63.96%, Train F1 Score: 66.56%
#
# Tracked Validation Score improved (0.5418 --> 0.5402). Saving model...
# Epoch [8/100] with Learning Rate: [0.001]
# Loss: 0.5377
# Train Accuracy: 77.46% Train Precision: 70.34%, Train Recall: 63.65%, Train F1 Score: 66.29%
#
# Tracked Validation Score improved (0.5402 --> 0.5377). Saving model...
# Epoch [9/100] with Learning Rate: [0.001]
# Loss: 0.5360
# Train Accuracy: 77.62% Train Precision: 70.31%, Train Recall: 64.08%, Train F1 Score: 66.60%
#
# Tracked Validation Score improved (0.5377 --> 0.5360). Saving model...
# Epoch [10/100] with Learning Rate: [0.001]
# Loss: 0.5346
# Train Accuracy: 77.56% Train Precision: 71.21%, Train Recall: 64.63%, Train F1 Score: 67.41%
#
# Tracked Validation Score improved (0.5360 --> 0.5346). Saving model...
# Epoch [11/100] with Learning Rate: [0.001]
# Loss: 0.5328
# Train Accuracy: 77.66% Train Precision: 72.05%, Train Recall: 65.35%, Train F1 Score: 68.13%
#
# Tracked Validation Score improved (0.5346 --> 0.5328). Saving model...
# Epoch [12/100] with Learning Rate: [0.001]
# Loss: 0.5317
# Train Accuracy: 77.67% Train Precision: 71.50%, Train Recall: 65.00%, Train F1 Score: 67.74%
#
# Tracked Validation Score improved (0.5328 --> 0.5317). Saving model...
# Epoch [13/100] with Learning Rate: [0.001]
# Loss: 0.5309
# Train Accuracy: 77.75% Train Precision: 71.34%, Train Recall: 64.91%, Train F1 Score: 67.70%
#
# Tracked Validation Score improved (0.5317 --> 0.5309). Saving model...
# Epoch [14/100] with Learning Rate: [0.001]
# Loss: 0.5296
# Train Accuracy: 77.75% Train Precision: 71.57%, Train Recall: 65.13%, Train F1 Score: 67.86%
#
# Tracked Validation Score improved (0.5309 --> 0.5296). Saving model...
# Epoch [15/100] with Learning Rate: [0.001]
# Loss: 0.5285
# Train Accuracy: 77.83% Train Precision: 72.47%, Train Recall: 65.66%, Train F1 Score: 68.57%
#
# Tracked Validation Score improved (0.5296 --> 0.5285). Saving model...
# Epoch [16/100] with Learning Rate: [0.001]
# Loss: 0.5268
# Train Accuracy: 77.88% Train Precision: 72.72%, Train Recall: 65.86%, Train F1 Score: 68.72%
#
# Tracked Validation Score improved (0.5285 --> 0.5268). Saving model...
# Epoch [17/100] with Learning Rate: [0.001]
# Loss: 0.5262
# Train Accuracy: 77.94% Train Precision: 72.80%, Train Recall: 65.83%, Train F1 Score: 68.85%
#
# Tracked Validation Score improved (0.5268 --> 0.5262). Saving model...
# Epoch [18/100] with Learning Rate: [0.001]
# Loss: 0.5251
# Train Accuracy: 77.94% Train Precision: 72.10%, Train Recall: 65.93%, Train F1 Score: 68.51%
#
# Tracked Validation Score improved (0.5262 --> 0.5251). Saving model...
# Epoch [19/100] with Learning Rate: [0.001]
# Loss: 0.5244
# Train Accuracy: 77.94% Train Precision: 73.36%, Train Recall: 66.62%, Train F1 Score: 69.52%
#
# Tracked Validation Score improved (0.5251 --> 0.5244). Saving model...
# Epoch [20/100] with Learning Rate: [0.001]
# Loss: 0.5239
# Train Accuracy: 78.02% Train Precision: 73.38%, Train Recall: 66.83%, Train F1 Score: 69.66%
#
# Tracked Validation Score improved (0.5244 --> 0.5239). Saving model...
# Epoch [21/100] with Learning Rate: [0.001]
# Loss: 0.5226
# Train Accuracy: 77.99% Train Precision: 73.03%, Train Recall: 65.53%, Train F1 Score: 68.71%
#
# Tracked Validation Score improved (0.5239 --> 0.5226). Saving model...
# Epoch [22/100] with Learning Rate: [0.001]
# Loss: 0.5220
# Train Accuracy: 78.02% Train Precision: 72.75%, Train Recall: 65.79%, Train F1 Score: 68.76%
#
# Tracked Validation Score improved (0.5226 --> 0.5220). Saving model...
# Epoch [23/100] with Learning Rate: [0.001]
# Loss: 0.5223
# Train Accuracy: 77.99% Train Precision: 72.74%, Train Recall: 66.17%, Train F1 Score: 69.00%
#
# EarlyStopping counter: 1 out of 30
# Epoch [24/100] with Learning Rate: [0.001]
# Loss: 0.5202
# Train Accuracy: 78.13% Train Precision: 72.73%, Train Recall: 65.69%, Train F1 Score: 68.73%
#
# Tracked Validation Score improved (0.5220 --> 0.5202). Saving model...
# Epoch [25/100] with Learning Rate: [0.001]
# Loss: 0.5202
# Train Accuracy: 78.15% Train Precision: 72.92%, Train Recall: 65.90%, Train F1 Score: 68.94%
#
# EarlyStopping counter: 1 out of 30
# Epoch [26/100] with Learning Rate: [0.001]
# Loss: 0.5184
# Train Accuracy: 78.21% Train Precision: 73.79%, Train Recall: 66.75%, Train F1 Score: 69.81%
#
# Tracked Validation Score improved (0.5202 --> 0.5184). Saving model...
# Epoch [27/100] with Learning Rate: [0.001]
# Loss: 0.5178
# Train Accuracy: 78.21% Train Precision: 73.41%, Train Recall: 66.51%, Train F1 Score: 69.51%
#
# Tracked Validation Score improved (0.5184 --> 0.5178). Saving model...
# Epoch [28/100] with Learning Rate: [0.001]
# Loss: 0.5176
# Train Accuracy: 78.28% Train Precision: 74.05%, Train Recall: 66.81%, Train F1 Score: 69.94%
#
# Tracked Validation Score improved (0.5178 --> 0.5176). Saving model...
# Epoch [29/100] with Learning Rate: [0.001]
# Loss: 0.5175
# Train Accuracy: 78.20% Train Precision: 73.26%, Train Recall: 66.26%, Train F1 Score: 69.30%
#
# Tracked Validation Score improved (0.5176 --> 0.5175). Saving model...
# Epoch [30/100] with Learning Rate: [0.001]
# Loss: 0.5165
# Train Accuracy: 78.36% Train Precision: 73.98%, Train Recall: 66.64%, Train F1 Score: 69.77%
#
# Tracked Validation Score improved (0.5175 --> 0.5165). Saving model...
# Epoch [31/100] with Learning Rate: [0.001]
# Loss: 0.5153
# Train Accuracy: 78.33% Train Precision: 74.09%, Train Recall: 67.23%, Train F1 Score: 70.21%
#
# Tracked Validation Score improved (0.5165 --> 0.5153). Saving model...
# Epoch [32/100] with Learning Rate: [0.001]
# Loss: 0.5151
# Train Accuracy: 78.33% Train Precision: 73.79%, Train Recall: 66.69%, Train F1 Score: 69.78%
#
# Tracked Validation Score improved (0.5153 --> 0.5151). Saving model...
# Epoch [33/100] with Learning Rate: [0.001]
# Loss: 0.5143
# Train Accuracy: 78.32% Train Precision: 73.08%, Train Recall: 66.23%, Train F1 Score: 69.23%
#
# Tracked Validation Score improved (0.5151 --> 0.5143). Saving model...
# Epoch [34/100] with Learning Rate: [0.001]
# Loss: 0.5135
# Train Accuracy: 78.31% Train Precision: 73.17%, Train Recall: 66.43%, Train F1 Score: 69.36%
#
# Tracked Validation Score improved (0.5143 --> 0.5135). Saving model...
# Epoch [35/100] with Learning Rate: [0.001]
# Loss: 0.5131
# Train Accuracy: 78.38% Train Precision: 73.36%, Train Recall: 66.64%, Train F1 Score: 69.57%
#
# Tracked Validation Score improved (0.5135 --> 0.5131). Saving model...
# Epoch [36/100] with Learning Rate: [0.001]
# Loss: 0.5124
# Train Accuracy: 78.38% Train Precision: 73.38%, Train Recall: 66.97%, Train F1 Score: 69.81%
#
# Tracked Validation Score improved (0.5131 --> 0.5124). Saving model...
# Epoch [37/100] with Learning Rate: [0.001]
# Loss: 0.5122
# Train Accuracy: 78.46% Train Precision: 73.31%, Train Recall: 67.09%, Train F1 Score: 69.82%
#
# Tracked Validation Score improved (0.5124 --> 0.5122). Saving model...
# Epoch [38/100] with Learning Rate: [0.001]
# Loss: 0.5119
# Train Accuracy: 78.37% Train Precision: 72.75%, Train Recall: 66.50%, Train F1 Score: 69.23%
#
# Tracked Validation Score improved (0.5122 --> 0.5119). Saving model...
# Epoch [39/100] with Learning Rate: [0.001]
# Loss: 0.5115
# Train Accuracy: 78.58% Train Precision: 74.27%, Train Recall: 66.88%, Train F1 Score: 70.09%
#
# Tracked Validation Score improved (0.5119 --> 0.5115). Saving model...
# Epoch [40/100] with Learning Rate: [0.001]
# Loss: 0.5099
# Train Accuracy: 78.48% Train Precision: 74.13%, Train Recall: 66.81%, Train F1 Score: 69.96%
#
# Tracked Validation Score improved (0.5115 --> 0.5099). Saving model...
# Epoch [41/100] with Learning Rate: [0.001]
# Loss: 0.5113
# Train Accuracy: 78.49% Train Precision: 72.89%, Train Recall: 66.46%, Train F1 Score: 69.29%
#
# EarlyStopping counter: 1 out of 30
# Epoch [42/100] with Learning Rate: [0.001]
# Loss: 0.5097
# Train Accuracy: 78.48% Train Precision: 74.13%, Train Recall: 66.38%, Train F1 Score: 69.71%
#
# Tracked Validation Score improved (0.5099 --> 0.5097). Saving model...
# Epoch [43/100] with Learning Rate: [0.001]
# Loss: 0.5094
# Train Accuracy: 78.49% Train Precision: 74.22%, Train Recall: 67.17%, Train F1 Score: 70.25%
#
# Tracked Validation Score improved (0.5097 --> 0.5094). Saving model...
# Epoch [44/100] with Learning Rate: [0.001]
# Loss: 0.5089
# Train Accuracy: 78.46% Train Precision: 73.57%, Train Recall: 66.56%, Train F1 Score: 69.59%
#
# Tracked Validation Score improved (0.5094 --> 0.5089). Saving model...
# Epoch [45/100] with Learning Rate: [0.001]
# Loss: 0.5079
# Train Accuracy: 78.51% Train Precision: 74.35%, Train Recall: 67.15%, Train F1 Score: 70.29%
#
# Tracked Validation Score improved (0.5089 --> 0.5079). Saving model...
# Epoch [46/100] with Learning Rate: [0.001]
# Loss: 0.5072
# Train Accuracy: 78.54% Train Precision: 73.28%, Train Recall: 66.39%, Train F1 Score: 69.39%
#
# Tracked Validation Score improved (0.5079 --> 0.5072). Saving model...
# Epoch [47/100] with Learning Rate: [0.001]
# Loss: 0.5078
# Train Accuracy: 78.69% Train Precision: 74.21%, Train Recall: 67.37%, Train F1 Score: 70.37%
#
# EarlyStopping counter: 1 out of 30
# Epoch [48/100] with Learning Rate: [0.001]
# Loss: 0.5070
# Train Accuracy: 78.58% Train Precision: 73.54%, Train Recall: 66.30%, Train F1 Score: 69.42%
#
# Tracked Validation Score improved (0.5072 --> 0.5070). Saving model...
# Epoch [49/100] with Learning Rate: [0.001]
# Loss: 0.5068
# Train Accuracy: 78.64% Train Precision: 73.58%, Train Recall: 66.69%, Train F1 Score: 69.71%
#
# Tracked Validation Score improved (0.5070 --> 0.5068). Saving model...
# Epoch [50/100] with Learning Rate: [0.001]
# Loss: 0.5065
# Train Accuracy: 78.63% Train Precision: 73.45%, Train Recall: 66.56%, Train F1 Score: 69.57%
#
# Tracked Validation Score improved (0.5068 --> 0.5065). Saving model...
# Epoch [51/100] with Learning Rate: [0.001]
# Loss: 0.5060
# Train Accuracy: 78.52% Train Precision: 74.27%, Train Recall: 67.38%, Train F1 Score: 70.39%
#
# Tracked Validation Score improved (0.5065 --> 0.5060). Saving model...
# Epoch [52/100] with Learning Rate: [0.001]
# Loss: 0.5056
# Train Accuracy: 78.56% Train Precision: 74.14%, Train Recall: 67.07%, Train F1 Score: 70.15%
#
# Tracked Validation Score improved (0.5060 --> 0.5056). Saving model...
# Epoch [53/100] with Learning Rate: [0.001]
# Loss: 0.5051
# Train Accuracy: 78.77% Train Precision: 74.53%, Train Recall: 67.01%, Train F1 Score: 70.27%
#
# Tracked Validation Score improved (0.5056 --> 0.5051). Saving model...
# Epoch [54/100] with Learning Rate: [0.001]
# Loss: 0.5046
# Train Accuracy: 78.65% Train Precision: 74.15%, Train Recall: 67.03%, Train F1 Score: 70.14%
#
# Tracked Validation Score improved (0.5051 --> 0.5046). Saving model...
# Epoch [55/100] with Learning Rate: [0.001]
# Loss: 0.5040
# Train Accuracy: 78.63% Train Precision: 73.83%, Train Recall: 66.85%, Train F1 Score: 69.87%
#
# Tracked Validation Score improved (0.5046 --> 0.5040). Saving model...
# Epoch [56/100] with Learning Rate: [0.001]
# Loss: 0.5040
# Train Accuracy: 78.69% Train Precision: 74.66%, Train Recall: 66.64%, Train F1 Score: 70.07%
#
# EarlyStopping counter: 1 out of 30
# Epoch [57/100] with Learning Rate: [0.001]
# Loss: 0.5035
# Train Accuracy: 78.76% Train Precision: 74.54%, Train Recall: 67.24%, Train F1 Score: 70.41%
#
# Tracked Validation Score improved (0.5040 --> 0.5035). Saving model...
# Epoch [58/100] with Learning Rate: [0.001]
# Loss: 0.5040
# Train Accuracy: 78.70% Train Precision: 74.59%, Train Recall: 66.87%, Train F1 Score: 70.19%
#
# EarlyStopping counter: 1 out of 30
# Epoch [59/100] with Learning Rate: [0.001]
# Loss: 0.5031
# Train Accuracy: 78.66% Train Precision: 74.38%, Train Recall: 66.90%, Train F1 Score: 70.13%
#
# Tracked Validation Score improved (0.5035 --> 0.5031). Saving model...
# Epoch [60/100] with Learning Rate: [0.001]
# Loss: 0.5031
# Train Accuracy: 78.69% Train Precision: 73.70%, Train Recall: 66.74%, Train F1 Score: 69.76%
#
# Tracked Validation Score improved (0.5031 --> 0.5031). Saving model...
# Epoch [61/100] with Learning Rate: [0.001]
# Loss: 0.5019
# Train Accuracy: 78.74% Train Precision: 74.42%, Train Recall: 67.48%, Train F1 Score: 70.52%
#
# Tracked Validation Score improved (0.5031 --> 0.5019). Saving model...
# Epoch [62/100] with Learning Rate: [0.001]
# Loss: 0.5019
# Train Accuracy: 78.75% Train Precision: 74.13%, Train Recall: 67.42%, Train F1 Score: 70.33%
#
# EarlyStopping counter: 1 out of 30
# Epoch [63/100] with Learning Rate: [0.001]
# Loss: 0.5022
# Train Accuracy: 78.81% Train Precision: 74.22%, Train Recall: 66.92%, Train F1 Score: 70.09%
#
# EarlyStopping counter: 2 out of 30
# Epoch [64/100] with Learning Rate: [0.001]
# Loss: 0.5020
# Train Accuracy: 78.76% Train Precision: 74.21%, Train Recall: 67.43%, Train F1 Score: 70.39%
#
# EarlyStopping counter: 3 out of 30
# Epoch [65/100] with Learning Rate: [0.001]
# Loss: 0.5017
# Train Accuracy: 78.79% Train Precision: 75.05%, Train Recall: 67.10%, Train F1 Score: 70.51%
#
# Tracked Validation Score improved (0.5019 --> 0.5017). Saving model...
# Epoch [66/100] with Learning Rate: [0.001]
# Loss: 0.5010
# Train Accuracy: 78.74% Train Precision: 74.32%, Train Recall: 67.13%, Train F1 Score: 70.22%
#
# Tracked Validation Score improved (0.5017 --> 0.5010). Saving model...
# Epoch [67/100] with Learning Rate: [0.001]
# Loss: 0.5012
# Train Accuracy: 78.83% Train Precision: 74.95%, Train Recall: 67.21%, Train F1 Score: 70.55%
#
# EarlyStopping counter: 1 out of 30
# Epoch [68/100] with Learning Rate: [0.001]
# Loss: 0.5002
# Train Accuracy: 78.76% Train Precision: 74.07%, Train Recall: 67.05%, Train F1 Score: 70.11%
#
# Tracked Validation Score improved (0.5010 --> 0.5002). Saving model...
# Epoch [69/100] with Learning Rate: [0.001]
# Loss: 0.5001
# Train Accuracy: 78.84% Train Precision: 74.61%, Train Recall: 67.54%, Train F1 Score: 70.61%
#
# Tracked Validation Score improved (0.5002 --> 0.5001). Saving model...
# Epoch [70/100] with Learning Rate: [0.001]
# Loss: 0.4995
# Train Accuracy: 78.81% Train Precision: 74.26%, Train Recall: 67.26%, Train F1 Score: 70.30%
#
# Tracked Validation Score improved (0.5001 --> 0.4995). Saving model...
# Epoch [71/100] with Learning Rate: [0.001]
# Loss: 0.4999
# Train Accuracy: 78.93% Train Precision: 74.57%, Train Recall: 67.09%, Train F1 Score: 70.31%
#
# EarlyStopping counter: 1 out of 30
# Epoch [72/100] with Learning Rate: [0.001]
# Loss: 0.5001
# Train Accuracy: 78.82% Train Precision: 74.35%, Train Recall: 67.53%, Train F1 Score: 70.53%
#
# EarlyStopping counter: 2 out of 30
# Epoch [73/100] with Learning Rate: [0.001]
# Loss: 0.4994
# Train Accuracy: 78.82% Train Precision: 74.71%, Train Recall: 67.43%, Train F1 Score: 70.60%
#
# Tracked Validation Score improved (0.4995 --> 0.4994). Saving model...
# Epoch [74/100] with Learning Rate: [0.001]
# Loss: 0.4993
# Train Accuracy: 78.85% Train Precision: 74.35%, Train Recall: 67.15%, Train F1 Score: 70.27%
#
# Tracked Validation Score improved (0.4994 --> 0.4993). Saving model...
# Epoch [75/100] with Learning Rate: [0.001]
# Loss: 0.4981
# Train Accuracy: 78.87% Train Precision: 75.09%, Train Recall: 67.45%, Train F1 Score: 70.74%
#
# Tracked Validation Score improved (0.4993 --> 0.4981). Saving model...
# Epoch [76/100] with Learning Rate: [0.001]
# Loss: 0.4992
# Train Accuracy: 78.85% Train Precision: 74.34%, Train Recall: 66.98%, Train F1 Score: 70.17%
#
# EarlyStopping counter: 1 out of 30
# Epoch [77/100] with Learning Rate: [0.001]
# Loss: 0.4984
# Train Accuracy: 78.95% Train Precision: 74.22%, Train Recall: 67.40%, Train F1 Score: 70.40%
#
# EarlyStopping counter: 2 out of 30
# Epoch [78/100] with Learning Rate: [0.001]
# Loss: 0.4980
# Train Accuracy: 78.81% Train Precision: 74.03%, Train Recall: 66.72%, Train F1 Score: 69.88%
#
# Tracked Validation Score improved (0.4981 --> 0.4980). Saving model...
# Epoch [79/100] with Learning Rate: [0.001]
# Loss: 0.4985
# Train Accuracy: 78.89% Train Precision: 74.51%, Train Recall: 67.36%, Train F1 Score: 70.46%
#
# EarlyStopping counter: 1 out of 30
# Epoch [80/100] with Learning Rate: [0.001]
# Loss: 0.4977
# Train Accuracy: 78.88% Train Precision: 74.10%, Train Recall: 67.23%, Train F1 Score: 70.25%
#
# Tracked Validation Score improved (0.4980 --> 0.4977). Saving model...
# Epoch [81/100] with Learning Rate: [0.001]
# Loss: 0.4971
# Train Accuracy: 78.88% Train Precision: 73.98%, Train Recall: 66.68%, Train F1 Score: 69.83%
#
# Tracked Validation Score improved (0.4977 --> 0.4971). Saving model...
# Epoch [82/100] with Learning Rate: [0.001]
# Loss: 0.4976
# Train Accuracy: 78.89% Train Precision: 74.16%, Train Recall: 67.27%, Train F1 Score: 70.28%
#
# EarlyStopping counter: 1 out of 30
# Epoch [83/100] with Learning Rate: [0.001]
# Loss: 0.4973
# Train Accuracy: 78.96% Train Precision: 74.29%, Train Recall: 67.18%, Train F1 Score: 70.28%
#
# EarlyStopping counter: 2 out of 30
# Epoch [84/100] with Learning Rate: [0.001]
# Loss: 0.4967
# Train Accuracy: 78.89% Train Precision: 74.11%, Train Recall: 66.68%, Train F1 Score: 69.88%
#
# Tracked Validation Score improved (0.4971 --> 0.4967). Saving model...
# Epoch [85/100] with Learning Rate: [0.001]
# Loss: 0.4968
# Train Accuracy: 78.89% Train Precision: 73.99%, Train Recall: 66.75%, Train F1 Score: 69.88%
#
# EarlyStopping counter: 1 out of 30
# Epoch [86/100] with Learning Rate: [0.001]
# Loss: 0.4982
# Train Accuracy: 78.85% Train Precision: 73.48%, Train Recall: 66.42%, Train F1 Score: 69.50%
#
# EarlyStopping counter: 2 out of 30
# Epoch [87/100] with Learning Rate: [0.001]
# Loss: 0.4961
# Train Accuracy: 78.94% Train Precision: 74.18%, Train Recall: 66.86%, Train F1 Score: 70.01%
#
# Tracked Validation Score improved (0.4967 --> 0.4961). Saving model...
# Epoch [88/100] with Learning Rate: [0.001]
# Loss: 0.4960
# Train Accuracy: 78.99% Train Precision: 73.99%, Train Recall: 67.16%, Train F1 Score: 70.14%
#
# Tracked Validation Score improved (0.4961 --> 0.4960). Saving model...
# Epoch [89/100] with Learning Rate: [0.001]
# Loss: 0.4966
# Train Accuracy: 79.01% Train Precision: 74.25%, Train Recall: 67.16%, Train F1 Score: 70.24%
#
# EarlyStopping counter: 1 out of 30
# Epoch [90/100] with Learning Rate: [0.001]
# Loss: 0.4959
# Train Accuracy: 78.98% Train Precision: 74.74%, Train Recall: 67.28%, Train F1 Score: 70.50%
#
# Tracked Validation Score improved (0.4960 --> 0.4959). Saving model...
# Epoch [91/100] with Learning Rate: [0.001]
# Loss: 0.4953
# Train Accuracy: 78.88% Train Precision: 73.82%, Train Recall: 66.55%, Train F1 Score: 69.69%
#
# Tracked Validation Score improved (0.4959 --> 0.4953). Saving model...
# Epoch [92/100] with Learning Rate: [0.001]
# Loss: 0.4951
# Train Accuracy: 79.04% Train Precision: 74.29%, Train Recall: 67.51%, Train F1 Score: 70.47%
#
# Tracked Validation Score improved (0.4953 --> 0.4951). Saving model...
# Epoch [93/100] with Learning Rate: [0.001]
# Loss: 0.4961
# Train Accuracy: 78.94% Train Precision: 74.71%, Train Recall: 67.49%, Train F1 Score: 70.63%
#
# EarlyStopping counter: 1 out of 30
# Epoch [94/100] with Learning Rate: [0.001]
# Loss: 0.4956
# Train Accuracy: 78.98% Train Precision: 74.00%, Train Recall: 66.53%, Train F1 Score: 69.73%
#
# EarlyStopping counter: 2 out of 30
# Epoch [95/100] with Learning Rate: [0.001]
# Loss: 0.4940
# Train Accuracy: 78.96% Train Precision: 74.81%, Train Recall: 67.86%, Train F1 Score: 70.91%
#
# Tracked Validation Score improved (0.4951 --> 0.4940). Saving model...
# Epoch [96/100] with Learning Rate: [0.001]
# Loss: 0.4953
# Train Accuracy: 79.06% Train Precision: 75.47%, Train Recall: 67.59%, Train F1 Score: 70.96%
#
# EarlyStopping counter: 1 out of 30
# Epoch [97/100] with Learning Rate: [0.001]
# Loss: 0.4948
# Train Accuracy: 79.01% Train Precision: 74.59%, Train Recall: 67.10%, Train F1 Score: 70.35%
#
# EarlyStopping counter: 2 out of 30
# Epoch [98/100] with Learning Rate: [0.001]
# Loss: 0.4949
# Train Accuracy: 78.94% Train Precision: 73.93%, Train Recall: 67.07%, Train F1 Score: 70.05%
#
# EarlyStopping counter: 3 out of 30
# Epoch [99/100] with Learning Rate: [0.001]
# Loss: 0.4939
# Train Accuracy: 79.12% Train Precision: 75.28%, Train Recall: 67.73%, Train F1 Score: 71.01%
#
# Tracked Validation Score improved (0.4940 --> 0.4939). Saving model...
# Epoch [100/100] with Learning Rate: [0.001]
# Loss: 0.4940
# Train Accuracy: 79.04% Train Precision: 74.52%, Train Recall: 67.33%, Train F1 Score: 70.46%
#
# EarlyStopping counter: 1 out of 30
#
# Fold 1 Performance:
#
# Best Train Loss: 0.4939
# Best Train Accuracy: 79.12%
# Best Train Precision: 75.28%
# Best Train Recall: 67.73%
# Best Train F1 Score: 71.01%
# Fold 2/10
# Epoch [1/100] with Learning Rate: [0.001]
# Loss: 0.6284
# Train Accuracy: 74.32% Train Precision: 59.16%, Train Recall: 54.30%, Train F1 Score: 55.11%
#
# Tracked Validation Score improved (-inf --> 0.6284). Saving model...
# Epoch [2/100] with Learning Rate: [0.001]
# Loss: 0.5607
# Train Accuracy: 76.70% Train Precision: 66.90%, Train Recall: 61.04%, Train F1 Score: 63.40%
#
# Tracked Validation Score improved (0.6284 --> 0.5607). Saving model...
# Epoch [3/100] with Learning Rate: [0.001]
# Loss: 0.5541
# Train Accuracy: 76.91% Train Precision: 67.29%, Train Recall: 61.63%, Train F1 Score: 63.99%
#
# Tracked Validation Score improved (0.5607 --> 0.5541). Saving model...
# Epoch [4/100] with Learning Rate: [0.001]
# Loss: 0.5507
# Train Accuracy: 77.07% Train Precision: 68.74%, Train Recall: 62.59%, Train F1 Score: 65.24%
#
# Tracked Validation Score improved (0.5541 --> 0.5507). Saving model...
# Epoch [5/100] with Learning Rate: [0.001]
# Loss: 0.5475
# Train Accuracy: 77.24% Train Precision: 69.36%, Train Recall: 62.82%, Train F1 Score: 65.57%
#
# Tracked Validation Score improved (0.5507 --> 0.5475). Saving model...
# Epoch [6/100] with Learning Rate: [0.001]
# Loss: 0.5446
# Train Accuracy: 77.29% Train Precision: 70.73%, Train Recall: 63.59%, Train F1 Score: 66.64%
#
# Tracked Validation Score improved (0.5475 --> 0.5446). Saving model...
# Epoch [7/100] with Learning Rate: [0.001]
# Loss: 0.5426
# Train Accuracy: 77.36% Train Precision: 71.05%, Train Recall: 63.68%, Train F1 Score: 66.80%
#
# Tracked Validation Score improved (0.5446 --> 0.5426). Saving model...
# Epoch [8/100] with Learning Rate: [0.001]
# Loss: 0.5400
# Train Accuracy: 77.50% Train Precision: 71.06%, Train Recall: 63.91%, Train F1 Score: 66.93%
#
# Tracked Validation Score improved (0.5426 --> 0.5400). Saving model...
# Epoch [9/100] with Learning Rate: [0.001]
# Loss: 0.5383
# Train Accuracy: 77.51% Train Precision: 71.93%, Train Recall: 64.44%, Train F1 Score: 67.56%
#
# Tracked Validation Score improved (0.5400 --> 0.5383). Saving model...
# Epoch [10/100] with Learning Rate: [0.001]
# Loss: 0.5366
# Train Accuracy: 77.54% Train Precision: 72.09%, Train Recall: 64.94%, Train F1 Score: 67.90%
#
# Tracked Validation Score improved (0.5383 --> 0.5366). Saving model...
# Epoch [11/100] with Learning Rate: [0.001]
# Loss: 0.5350
# Train Accuracy: 77.64% Train Precision: 71.70%, Train Recall: 64.45%, Train F1 Score: 67.56%
#
# Tracked Validation Score improved (0.5366 --> 0.5350). Saving model...
# Epoch [12/100] with Learning Rate: [0.001]
# Loss: 0.5339
# Train Accuracy: 77.71% Train Precision: 72.07%, Train Recall: 64.68%, Train F1 Score: 67.81%
#
# Tracked Validation Score improved (0.5350 --> 0.5339). Saving model...
# Epoch [13/100] with Learning Rate: [0.001]
# Loss: 0.5327
# Train Accuracy: 77.75% Train Precision: 73.15%, Train Recall: 65.47%, Train F1 Score: 68.71%
#
# Tracked Validation Score improved (0.5339 --> 0.5327). Saving model...
# Epoch [14/100] with Learning Rate: [0.001]
# Loss: 0.5305
# Train Accuracy: 77.79% Train Precision: 73.11%, Train Recall: 65.27%, Train F1 Score: 68.62%
#
# Tracked Validation Score improved (0.5327 --> 0.5305). Saving model...
# Epoch [15/100] with Learning Rate: [0.001]
# Loss: 0.5295
# Train Accuracy: 77.84% Train Precision: 72.69%, Train Recall: 65.61%, Train F1 Score: 68.68%
#
# Tracked Validation Score improved (0.5305 --> 0.5295). Saving model...
# Epoch [16/100] with Learning Rate: [0.001]
# Loss: 0.5288
# Train Accuracy: 77.86% Train Precision: 72.58%, Train Recall: 65.63%, Train F1 Score: 68.55%
#
# Tracked Validation Score improved (0.5295 --> 0.5288). Saving model...
# Epoch [17/100] with Learning Rate: [0.001]
# Loss: 0.5277
# Train Accuracy: 77.93% Train Precision: 73.48%, Train Recall: 66.09%, Train F1 Score: 69.30%
#
# Tracked Validation Score improved (0.5288 --> 0.5277). Saving model...
# Epoch [18/100] with Learning Rate: [0.001]
# Loss: 0.5268
# Train Accuracy: 77.99% Train Precision: 72.77%, Train Recall: 65.62%, Train F1 Score: 68.73%
#
# Tracked Validation Score improved (0.5277 --> 0.5268). Saving model...
# Epoch [19/100] with Learning Rate: [0.001]
# Loss: 0.5255
# Train Accuracy: 78.01% Train Precision: 73.66%, Train Recall: 66.16%, Train F1 Score: 69.40%
#
# Tracked Validation Score improved (0.5268 --> 0.5255). Saving model...
# Epoch [20/100] with Learning Rate: [0.001]
# Loss: 0.5252
# Train Accuracy: 77.95% Train Precision: 73.94%, Train Recall: 66.51%, Train F1 Score: 69.72%
#
# Tracked Validation Score improved (0.5255 --> 0.5252). Saving model...
# Epoch [21/100] with Learning Rate: [0.001]
# Loss: 0.5241
# Train Accuracy: 77.94% Train Precision: 73.05%, Train Recall: 65.66%, Train F1 Score: 68.84%
#
# Tracked Validation Score improved (0.5252 --> 0.5241). Saving model...
# Epoch [22/100] with Learning Rate: [0.001]
# Loss: 0.5240
# Train Accuracy: 78.07% Train Precision: 73.47%, Train Recall: 65.91%, Train F1 Score: 69.19%
#
# Tracked Validation Score improved (0.5241 --> 0.5240). Saving model...
# Epoch [23/100] with Learning Rate: [0.001]
# Loss: 0.5229
# Train Accuracy: 78.06% Train Precision: 73.65%, Train Recall: 66.78%, Train F1 Score: 69.80%
#
# Tracked Validation Score improved (0.5240 --> 0.5229). Saving model...
# Epoch [24/100] with Learning Rate: [0.001]
# Loss: 0.5221
# Train Accuracy: 78.08% Train Precision: 73.62%, Train Recall: 66.62%, Train F1 Score: 69.65%
#
# Tracked Validation Score improved (0.5229 --> 0.5221). Saving model...
# Epoch [25/100] with Learning Rate: [0.001]
# Loss: 0.5215
# Train Accuracy: 78.10% Train Precision: 73.78%, Train Recall: 66.70%, Train F1 Score: 69.81%
#
# Tracked Validation Score improved (0.5221 --> 0.5215). Saving model...
# Epoch [26/100] with Learning Rate: [0.001]
# Loss: 0.5205
# Train Accuracy: 78.21% Train Precision: 73.22%, Train Recall: 65.67%, Train F1 Score: 68.90%
#
# Tracked Validation Score improved (0.5215 --> 0.5205). Saving model...
# Epoch [27/100] with Learning Rate: [0.001]
# Loss: 0.5200
# Train Accuracy: 78.13% Train Precision: 73.12%, Train Recall: 66.67%, Train F1 Score: 69.47%
#
# Tracked Validation Score improved (0.5205 --> 0.5200). Saving model...
# Epoch [28/100] with Learning Rate: [0.001]
# Loss: 0.5191
# Train Accuracy: 78.24% Train Precision: 73.67%, Train Recall: 66.26%, Train F1 Score: 69.48%
#
# Tracked Validation Score improved (0.5200 --> 0.5191). Saving model...
# Epoch [29/100] with Learning Rate: [0.001]
# Loss: 0.5185
# Train Accuracy: 78.28% Train Precision: 73.88%, Train Recall: 66.53%, Train F1 Score: 69.72%
#
# Tracked Validation Score improved (0.5191 --> 0.5185). Saving model...
# Epoch [30/100] with Learning Rate: [0.001]
# Loss: 0.5184
# Train Accuracy: 78.14% Train Precision: 73.48%, Train Recall: 66.39%, Train F1 Score: 69.49%
#
# Tracked Validation Score improved (0.5185 --> 0.5184). Saving model...
# Epoch [31/100] with Learning Rate: [0.001]
# Loss: 0.5172
# Train Accuracy: 78.24% Train Precision: 73.92%, Train Recall: 66.26%, Train F1 Score: 69.54%
#
# Tracked Validation Score improved (0.5184 --> 0.5172). Saving model...
# Epoch [32/100] with Learning Rate: [0.001]
# Loss: 0.5169
# Train Accuracy: 78.34% Train Precision: 74.40%, Train Recall: 67.04%, Train F1 Score: 70.21%
#
# Tracked Validation Score improved (0.5172 --> 0.5169). Saving model...
# Epoch [33/100] with Learning Rate: [0.001]
# Loss: 0.5173
# Train Accuracy: 78.39% Train Precision: 74.50%, Train Recall: 66.78%, Train F1 Score: 70.13%
#
# EarlyStopping counter: 1 out of 30
# Epoch [34/100] with Learning Rate: [0.001]
# Loss: 0.5154
# Train Accuracy: 78.34% Train Precision: 74.56%, Train Recall: 66.95%, Train F1 Score: 70.23%
#
# Tracked Validation Score improved (0.5169 --> 0.5154). Saving model...
# Epoch [35/100] with Learning Rate: [0.001]
# Loss: 0.5146
# Train Accuracy: 78.42% Train Precision: 74.04%, Train Recall: 66.98%, Train F1 Score: 70.09%
#
# Tracked Validation Score improved (0.5154 --> 0.5146). Saving model...
# Epoch [36/100] with Learning Rate: [0.001]
# Loss: 0.5144
# Train Accuracy: 78.37% Train Precision: 74.21%, Train Recall: 67.06%, Train F1 Score: 70.19%
#
# Tracked Validation Score improved (0.5146 --> 0.5144). Saving model...
# Epoch [37/100] with Learning Rate: [0.001]
# Loss: 0.5152
# Train Accuracy: 78.44% Train Precision: 74.57%, Train Recall: 67.39%, Train F1 Score: 70.55%
#
# EarlyStopping counter: 1 out of 30
# Epoch [38/100] with Learning Rate: [0.001]
# Loss: 0.5137
# Train Accuracy: 78.50% Train Precision: 74.47%, Train Recall: 67.03%, Train F1 Score: 70.28%
#
# Tracked Validation Score improved (0.5144 --> 0.5137). Saving model...
# Epoch [39/100] with Learning Rate: [0.001]
# Loss: 0.5131
# Train Accuracy: 78.43% Train Precision: 74.49%, Train Recall: 67.17%, Train F1 Score: 70.33%
#
# Tracked Validation Score improved (0.5137 --> 0.5131). Saving model...
# Epoch [40/100] with Learning Rate: [0.001]
# Loss: 0.5128
# Train Accuracy: 78.54% Train Precision: 74.69%, Train Recall: 67.41%, Train F1 Score: 70.57%
#
# Tracked Validation Score improved (0.5131 --> 0.5128). Saving model...
# Epoch [41/100] with Learning Rate: [0.001]
# Loss: 0.5120
# Train Accuracy: 78.42% Train Precision: 74.45%, Train Recall: 67.25%, Train F1 Score: 70.39%
#
# Tracked Validation Score improved (0.5128 --> 0.5120). Saving model...
# Epoch [42/100] with Learning Rate: [0.001]
# Loss: 0.5116
# Train Accuracy: 78.57% Train Precision: 74.53%, Train Recall: 67.29%, Train F1 Score: 70.45%
#
# Tracked Validation Score improved (0.5120 --> 0.5116). Saving model...
# Epoch [43/100] with Learning Rate: [0.001]
# Loss: 0.5113
# Train Accuracy: 78.53% Train Precision: 74.10%, Train Recall: 67.13%, Train F1 Score: 70.19%
#
# Tracked Validation Score improved (0.5116 --> 0.5113). Saving model...
# Epoch [44/100] with Learning Rate: [0.001]
# Loss: 0.5105
# Train Accuracy: 78.67% Train Precision: 74.60%, Train Recall: 67.48%, Train F1 Score: 70.57%
#
# Tracked Validation Score improved (0.5113 --> 0.5105). Saving model...
# Epoch [45/100] with Learning Rate: [0.001]
# Loss: 0.5103
# Train Accuracy: 78.57% Train Precision: 74.16%, Train Recall: 66.90%, Train F1 Score: 70.07%
#
# Tracked Validation Score improved (0.5105 --> 0.5103). Saving model...
# Epoch [46/100] with Learning Rate: [0.001]
# Loss: 0.5096
# Train Accuracy: 78.66% Train Precision: 74.54%, Train Recall: 67.44%, Train F1 Score: 70.55%
#
# Tracked Validation Score improved (0.5103 --> 0.5096). Saving model...
# Epoch [47/100] with Learning Rate: [0.001]
# Loss: 0.5101
# Train Accuracy: 78.54% Train Precision: 74.69%, Train Recall: 67.61%, Train F1 Score: 70.69%
#
# EarlyStopping counter: 1 out of 30
# Epoch [48/100] with Learning Rate: [0.001]
# Loss: 0.5090
# Train Accuracy: 78.70% Train Precision: 74.23%, Train Recall: 67.38%, Train F1 Score: 70.40%
#
# Tracked Validation Score improved (0.5096 --> 0.5090). Saving model...
# Epoch [49/100] with Learning Rate: [0.001]
# Loss: 0.5088
# Train Accuracy: 78.67% Train Precision: 75.35%, Train Recall: 68.11%, Train F1 Score: 71.26%
#
# Tracked Validation Score improved (0.5090 --> 0.5088). Saving model...
# Epoch [50/100] with Learning Rate: [0.001]
# Loss: 0.5088
# Train Accuracy: 78.68% Train Precision: 75.21%, Train Recall: 68.35%, Train F1 Score: 71.38%
#
# EarlyStopping counter: 1 out of 30
# Epoch [51/100] with Learning Rate: [0.001]
# Loss: 0.5074
# Train Accuracy: 78.72% Train Precision: 75.13%, Train Recall: 67.65%, Train F1 Score: 70.91%
#
# Tracked Validation Score improved (0.5088 --> 0.5074). Saving model...
# Epoch [52/100] with Learning Rate: [0.001]
# Loss: 0.5076
# Train Accuracy: 78.76% Train Precision: 74.94%, Train Recall: 67.89%, Train F1 Score: 70.99%
#
# EarlyStopping counter: 1 out of 30
# Epoch [53/100] with Learning Rate: [0.001]
# Loss: 0.5069
# Train Accuracy: 78.75% Train Precision: 74.97%, Train Recall: 67.93%, Train F1 Score: 71.04%
#
# Tracked Validation Score improved (0.5074 --> 0.5069). Saving model...
# Epoch [54/100] with Learning Rate: [0.001]
# Loss: 0.5066
# Train Accuracy: 78.81% Train Precision: 74.91%, Train Recall: 68.01%, Train F1 Score: 71.03%
#
# Tracked Validation Score improved (0.5069 --> 0.5066). Saving model...
# Epoch [55/100] with Learning Rate: [0.001]
# Loss: 0.5063
# Train Accuracy: 78.80% Train Precision: 75.57%, Train Recall: 68.24%, Train F1 Score: 71.45%
#
# Tracked Validation Score improved (0.5066 --> 0.5063). Saving model...
# Epoch [56/100] with Learning Rate: [0.001]
# Loss: 0.5071
# Train Accuracy: 78.73% Train Precision: 74.53%, Train Recall: 67.60%, Train F1 Score: 70.65%
#
# EarlyStopping counter: 1 out of 30
# Epoch [57/100] with Learning Rate: [0.001]
# Loss: 0.5057
# Train Accuracy: 78.75% Train Precision: 75.07%, Train Recall: 67.64%, Train F1 Score: 70.88%
#
# Tracked Validation Score improved (0.5063 --> 0.5057). Saving model...
# Epoch [58/100] with Learning Rate: [0.001]
# Loss: 0.5057
# Train Accuracy: 78.90% Train Precision: 74.78%, Train Recall: 67.57%, Train F1 Score: 70.72%
#
# EarlyStopping counter: 1 out of 30
# Epoch [59/100] with Learning Rate: [0.001]
# Loss: 0.5053
# Train Accuracy: 78.83% Train Precision: 74.94%, Train Recall: 67.71%, Train F1 Score: 70.85%
#
# Tracked Validation Score improved (0.5057 --> 0.5053). Saving model...
# Epoch [60/100] with Learning Rate: [0.001]
# Loss: 0.5041
# Train Accuracy: 78.86% Train Precision: 75.39%, Train Recall: 68.07%, Train F1 Score: 71.27%
#
# Tracked Validation Score improved (0.5053 --> 0.5041). Saving model...
# Epoch [61/100] with Learning Rate: [0.001]
# Loss: 0.5046
# Train Accuracy: 78.87% Train Precision: 75.21%, Train Recall: 67.83%, Train F1 Score: 71.06%
#
# EarlyStopping counter: 1 out of 30
# Epoch [62/100] with Learning Rate: [0.001]
# Loss: 0.5048
# Train Accuracy: 78.78% Train Precision: 75.30%, Train Recall: 67.66%, Train F1 Score: 70.98%
#
# EarlyStopping counter: 2 out of 30
# Epoch [63/100] with Learning Rate: [0.001]
# Loss: 0.5041
# Train Accuracy: 78.84% Train Precision: 75.08%, Train Recall: 67.37%, Train F1 Score: 70.71%
#
# Tracked Validation Score improved (0.5041 --> 0.5041). Saving model...
# Epoch [64/100] with Learning Rate: [0.001]
# Loss: 0.5042
# Train Accuracy: 78.88% Train Precision: 74.69%, Train Recall: 67.73%, Train F1 Score: 70.78%
#
# EarlyStopping counter: 1 out of 30
# Epoch [65/100] with Learning Rate: [0.001]
# Loss: 0.5030
# Train Accuracy: 78.95% Train Precision: 75.29%, Train Recall: 68.09%, Train F1 Score: 71.26%
#
# Tracked Validation Score improved (0.5041 --> 0.5030). Saving model...
# Epoch [66/100] with Learning Rate: [0.001]
# Loss: 0.5032
# Train Accuracy: 78.89% Train Precision: 75.25%, Train Recall: 68.01%, Train F1 Score: 71.18%
#
# EarlyStopping counter: 1 out of 30
# Epoch [67/100] with Learning Rate: [0.001]
# Loss: 0.5037
# Train Accuracy: 78.82% Train Precision: 74.80%, Train Recall: 68.19%, Train F1 Score: 71.11%
#
# EarlyStopping counter: 2 out of 30
# Epoch [68/100] with Learning Rate: [0.001]
# Loss: 0.5023
# Train Accuracy: 78.94% Train Precision: 74.84%, Train Recall: 67.65%, Train F1 Score: 70.82%
#
# Tracked Validation Score improved (0.5030 --> 0.5023). Saving model...
# Epoch [69/100] with Learning Rate: [0.001]
# Loss: 0.5035
# Train Accuracy: 78.88% Train Precision: 74.41%, Train Recall: 67.41%, Train F1 Score: 70.49%
#
# EarlyStopping counter: 1 out of 30
# Epoch [70/100] with Learning Rate: [0.001]
# Loss: 0.5018
# Train Accuracy: 79.00% Train Precision: 75.32%, Train Recall: 68.39%, Train F1 Score: 71.45%
#
# Tracked Validation Score improved (0.5023 --> 0.5018). Saving model...
# Epoch [71/100] with Learning Rate: [0.001]
# Loss: 0.5017
# Train Accuracy: 78.95% Train Precision: 74.65%, Train Recall: 67.96%, Train F1 Score: 70.91%
#
# Tracked Validation Score improved (0.5018 --> 0.5017). Saving model...
# Epoch [72/100] with Learning Rate: [0.001]
# Loss: 0.5025
# Train Accuracy: 79.00% Train Precision: 75.34%, Train Recall: 68.51%, Train F1 Score: 71.53%
#
# EarlyStopping counter: 1 out of 30
# Epoch [73/100] with Learning Rate: [0.001]
# Loss: 0.5015
# Train Accuracy: 78.98% Train Precision: 75.11%, Train Recall: 67.93%, Train F1 Score: 71.09%
#
# Tracked Validation Score improved (0.5017 --> 0.5015). Saving model...
# Epoch [74/100] with Learning Rate: [0.001]
# Loss: 0.5019
# Train Accuracy: 78.98% Train Precision: 75.10%, Train Recall: 67.39%, Train F1 Score: 70.72%
#
# EarlyStopping counter: 1 out of 30
# Epoch [75/100] with Learning Rate: [0.001]
# Loss: 0.5005
# Train Accuracy: 79.04% Train Precision: 75.67%, Train Recall: 68.72%, Train F1 Score: 71.76%
#
# Tracked Validation Score improved (0.5015 --> 0.5005). Saving model...
# Epoch [76/100] with Learning Rate: [0.001]
# Loss: 0.5011
# Train Accuracy: 79.05% Train Precision: 75.04%, Train Recall: 67.81%, Train F1 Score: 70.97%
#
# EarlyStopping counter: 1 out of 30
# Epoch [77/100] with Learning Rate: [0.001]
# Loss: 0.5027
# Train Accuracy: 79.07% Train Precision: 75.00%, Train Recall: 68.34%, Train F1 Score: 71.30%
#
# EarlyStopping counter: 2 out of 30
# Epoch [78/100] with Learning Rate: [0.001]
# Loss: 0.5005
# Train Accuracy: 79.02% Train Precision: 75.23%, Train Recall: 67.77%, Train F1 Score: 71.02%
#
# Tracked Validation Score improved (0.5005 --> 0.5005). Saving model...
# Epoch [79/100] with Learning Rate: [0.001]
# Loss: 0.5000
# Train Accuracy: 79.05% Train Precision: 75.05%, Train Recall: 67.58%, Train F1 Score: 70.81%
#
# Tracked Validation Score improved (0.5005 --> 0.5000). Saving model...
# Epoch [80/100] with Learning Rate: [0.001]
# Loss: 0.5002
# Train Accuracy: 79.08% Train Precision: 75.31%, Train Recall: 69.19%, Train F1 Score: 71.92%
#
# EarlyStopping counter: 1 out of 30
# Epoch [81/100] with Learning Rate: [0.001]
# Loss: 0.4996
# Train Accuracy: 79.15% Train Precision: 76.20%, Train Recall: 69.03%, Train F1 Score: 72.17%
#
# Tracked Validation Score improved (0.5000 --> 0.4996). Saving model...
# Epoch [82/100] with Learning Rate: [0.001]
# Loss: 0.4992
# Train Accuracy: 79.06% Train Precision: 75.19%, Train Recall: 68.05%, Train F1 Score: 71.17%
#
# Tracked Validation Score improved (0.4996 --> 0.4992). Saving model...
# Epoch [83/100] with Learning Rate: [0.001]
# Loss: 0.4992
# Train Accuracy: 79.03% Train Precision: 75.11%, Train Recall: 67.81%, Train F1 Score: 71.00%
#
# Tracked Validation Score improved (0.4992 --> 0.4992). Saving model...
# Epoch [84/100] with Learning Rate: [0.001]
# Loss: 0.4989
# Train Accuracy: 79.00% Train Precision: 75.21%, Train Recall: 68.18%, Train F1 Score: 71.27%
#
# Tracked Validation Score improved (0.4992 --> 0.4989). Saving model...
# Epoch [85/100] with Learning Rate: [0.001]
# Loss: 0.5002
# Train Accuracy: 79.06% Train Precision: 75.49%, Train Recall: 68.28%, Train F1 Score: 71.45%
#
# EarlyStopping counter: 1 out of 30
# Epoch [86/100] with Learning Rate: [0.001]
# Loss: 0.4983
# Train Accuracy: 79.07% Train Precision: 74.99%, Train Recall: 67.89%, Train F1 Score: 71.00%
#
# Tracked Validation Score improved (0.4989 --> 0.4983). Saving model...
# Epoch [87/100] with Learning Rate: [0.001]
# Loss: 0.4985
# Train Accuracy: 79.10% Train Precision: 75.89%, Train Recall: 68.63%, Train F1 Score: 71.82%
#
# EarlyStopping counter: 1 out of 30
# Epoch [88/100] with Learning Rate: [0.001]
# Loss: 0.4985
# Train Accuracy: 79.08% Train Precision: 75.45%, Train Recall: 68.32%, Train F1 Score: 71.43%
#
# EarlyStopping counter: 2 out of 30
# Epoch [89/100] with Learning Rate: [0.001]
# Loss: 0.4979
# Train Accuracy: 79.02% Train Precision: 75.77%, Train Recall: 69.03%, Train F1 Score: 72.03%
#
# Tracked Validation Score improved (0.4983 --> 0.4979). Saving model...
# Epoch [90/100] with Learning Rate: [0.001]
# Loss: 0.4984
# Train Accuracy: 79.07% Train Precision: 75.65%, Train Recall: 68.93%, Train F1 Score: 71.91%
#
# EarlyStopping counter: 1 out of 30
# Epoch [91/100] with Learning Rate: [0.001]
# Loss: 0.4980
# Train Accuracy: 79.12% Train Precision: 75.89%, Train Recall: 68.48%, Train F1 Score: 71.74%
#
# EarlyStopping counter: 2 out of 30
# Epoch [92/100] with Learning Rate: [0.001]
# Loss: 0.4987
# Train Accuracy: 79.12% Train Precision: 75.47%, Train Recall: 68.27%, Train F1 Score: 71.43%
#
# EarlyStopping counter: 3 out of 30
# Epoch [93/100] with Learning Rate: [0.001]
# Loss: 0.4978
# Train Accuracy: 79.16% Train Precision: 75.40%, Train Recall: 68.58%, Train F1 Score: 71.60%
#
# Tracked Validation Score improved (0.4979 --> 0.4978). Saving model...
# Epoch [94/100] with Learning Rate: [0.001]
# Loss: 0.4967
# Train Accuracy: 79.10% Train Precision: 74.95%, Train Recall: 68.28%, Train F1 Score: 71.22%
#
# Tracked Validation Score improved (0.4978 --> 0.4967). Saving model...
# Epoch [95/100] with Learning Rate: [0.001]
# Loss: 0.4968
# Train Accuracy: 79.17% Train Precision: 75.65%, Train Recall: 68.56%, Train F1 Score: 71.65%
#
# EarlyStopping counter: 1 out of 30
# Epoch [96/100] with Learning Rate: [0.001]
# Loss: 0.4972
# Train Accuracy: 79.16% Train Precision: 75.19%, Train Recall: 68.86%, Train F1 Score: 71.64%
#
# EarlyStopping counter: 2 out of 30
# Epoch [97/100] with Learning Rate: [0.001]
# Loss: 0.4968
# Train Accuracy: 79.10% Train Precision: 75.18%, Train Recall: 67.83%, Train F1 Score: 71.03%
#
# EarlyStopping counter: 3 out of 30
# Epoch [98/100] with Learning Rate: [0.001]
# Loss: 0.4956
# Train Accuracy: 79.27% Train Precision: 76.12%, Train Recall: 68.96%, Train F1 Score: 72.11%
#
# Tracked Validation Score improved (0.4967 --> 0.4956). Saving model...
# Epoch [99/100] with Learning Rate: [0.001]
# Loss: 0.4961
# Train Accuracy: 79.17% Train Precision: 75.53%, Train Recall: 68.37%, Train F1 Score: 71.49%
#
# EarlyStopping counter: 1 out of 30
# Epoch [100/100] with Learning Rate: [0.001]
# Loss: 0.4976
# Train Accuracy: 79.20% Train Precision: 75.49%, Train Recall: 68.57%, Train F1 Score: 71.63%
#
# EarlyStopping counter: 2 out of 30
#
# Fold 2 Performance:
#
# Best Train Loss: 0.4956
# Best Train Accuracy: 79.27%
# Best Train Precision: 76.12%
# Best Train Recall: 68.96%
# Best Train F1 Score: 72.11%
# Fold 3/10
# Epoch [1/100] with Learning Rate: [0.001]
# Loss: 0.6207
# Train Accuracy: 74.46% Train Precision: 61.11%, Train Recall: 54.83%, Train F1 Score: 57.25%
#
# Tracked Validation Score improved (-inf --> 0.6207). Saving model...
# Epoch [2/100] with Learning Rate: [0.001]
# Loss: 0.5613
# Train Accuracy: 76.76% Train Precision: 66.27%, Train Recall: 61.27%, Train F1 Score: 63.36%
#
# Tracked Validation Score improved (0.6207 --> 0.5613). Saving model...
# Epoch [3/100] with Learning Rate: [0.001]
# Loss: 0.5551
# Train Accuracy: 76.91% Train Precision: 67.84%, Train Recall: 62.80%, Train F1 Score: 64.98%
#
# Tracked Validation Score improved (0.5613 --> 0.5551). Saving model...
# Epoch [4/100] with Learning Rate: [0.001]
# Loss: 0.5506
# Train Accuracy: 76.95% Train Precision: 68.51%, Train Recall: 63.32%, Train F1 Score: 65.59%
#
# Tracked Validation Score improved (0.5551 --> 0.5506). Saving model...
# Epoch [5/100] with Learning Rate: [0.001]
# Loss: 0.5474
# Train Accuracy: 77.15% Train Precision: 68.07%, Train Recall: 63.37%, Train F1 Score: 65.36%
#
# Tracked Validation Score improved (0.5506 --> 0.5474). Saving model...
# Epoch [6/100] with Learning Rate: [0.001]
# Loss: 0.5435
# Train Accuracy: 77.35% Train Precision: 70.00%, Train Recall: 64.17%, Train F1 Score: 66.71%
#
# Tracked Validation Score improved (0.5474 --> 0.5435). Saving model...
# Epoch [7/100] with Learning Rate: [0.001]
# Loss: 0.5406
# Train Accuracy: 77.41% Train Precision: 69.88%, Train Recall: 64.70%, Train F1 Score: 66.86%
#
# Tracked Validation Score improved (0.5435 --> 0.5406). Saving model...
# Epoch [8/100] with Learning Rate: [0.001]
# Loss: 0.5390
# Train Accuracy: 77.46% Train Precision: 71.22%, Train Recall: 65.21%, Train F1 Score: 67.83%
#
# Tracked Validation Score improved (0.5406 --> 0.5390). Saving model...
# Epoch [9/100] with Learning Rate: [0.001]
# Loss: 0.5365
# Train Accuracy: 77.46% Train Precision: 70.73%, Train Recall: 65.25%, Train F1 Score: 67.64%
#
# Tracked Validation Score improved (0.5390 --> 0.5365). Saving model...
# Epoch [10/100] with Learning Rate: [0.001]
# Loss: 0.5351
# Train Accuracy: 77.57% Train Precision: 70.90%, Train Recall: 64.68%, Train F1 Score: 67.36%
#
# Tracked Validation Score improved (0.5365 --> 0.5351). Saving model...
# Epoch [11/100] with Learning Rate: [0.001]
# Loss: 0.5339
# Train Accuracy: 77.65% Train Precision: 71.11%, Train Recall: 64.89%, Train F1 Score: 67.57%
#
# Tracked Validation Score improved (0.5351 --> 0.5339). Saving model...
# Epoch [12/100] with Learning Rate: [0.001]
# Loss: 0.5320
# Train Accuracy: 77.65% Train Precision: 71.46%, Train Recall: 64.67%, Train F1 Score: 67.62%
#
# Tracked Validation Score improved (0.5339 --> 0.5320). Saving model...
# Epoch [13/100] with Learning Rate: [0.001]
# Loss: 0.5308
# Train Accuracy: 77.72% Train Precision: 71.93%, Train Recall: 65.63%, Train F1 Score: 68.40%
#
# Tracked Validation Score improved (0.5320 --> 0.5308). Saving model...
# Epoch [14/100] with Learning Rate: [0.001]
# Loss: 0.5297
# Train Accuracy: 77.73% Train Precision: 71.35%, Train Recall: 64.87%, Train F1 Score: 67.69%
#
# Tracked Validation Score improved (0.5308 --> 0.5297). Saving model...
# Epoch [15/100] with Learning Rate: [0.001]
# Loss: 0.5287
# Train Accuracy: 77.72% Train Precision: 72.03%, Train Recall: 65.56%, Train F1 Score: 68.39%
#
# Tracked Validation Score improved (0.5297 --> 0.5287). Saving model...
# Epoch [16/100] with Learning Rate: [0.001]
# Loss: 0.5277
# Train Accuracy: 77.75% Train Precision: 71.82%, Train Recall: 65.47%, Train F1 Score: 68.21%
#
# Tracked Validation Score improved (0.5287 --> 0.5277). Saving model...
# Epoch [17/100] with Learning Rate: [0.001]
# Loss: 0.5267
# Train Accuracy: 77.88% Train Precision: 72.36%, Train Recall: 65.80%, Train F1 Score: 68.64%
#
# Tracked Validation Score improved (0.5277 --> 0.5267). Saving model...
# Epoch [18/100] with Learning Rate: [0.001]
# Loss: 0.5256
# Train Accuracy: 77.83% Train Precision: 71.80%, Train Recall: 65.78%, Train F1 Score: 68.37%
#
# Tracked Validation Score improved (0.5267 --> 0.5256). Saving model...
# Epoch [19/100] with Learning Rate: [0.001]
# Loss: 0.5244
# Train Accuracy: 77.90% Train Precision: 71.82%, Train Recall: 65.67%, Train F1 Score: 68.31%
#
# Tracked Validation Score improved (0.5256 --> 0.5244). Saving model...
# Epoch [20/100] with Learning Rate: [0.001]
# Loss: 0.5238
# Train Accuracy: 77.92% Train Precision: 72.56%, Train Recall: 65.89%, Train F1 Score: 68.82%
#
# Tracked Validation Score improved (0.5244 --> 0.5238). Saving model...
# Epoch [21/100] with Learning Rate: [0.001]
# Loss: 0.5237
# Train Accuracy: 77.87% Train Precision: 72.30%, Train Recall: 66.04%, Train F1 Score: 68.74%
#
# Tracked Validation Score improved (0.5238 --> 0.5237). Saving model...
# Epoch [22/100] with Learning Rate: [0.001]
# Loss: 0.5213
# Train Accuracy: 78.05% Train Precision: 72.74%, Train Recall: 66.26%, Train F1 Score: 69.10%
#
# Tracked Validation Score improved (0.5237 --> 0.5213). Saving model...
# Epoch [23/100] with Learning Rate: [0.001]
# Loss: 0.5216
# Train Accuracy: 78.04% Train Precision: 72.80%, Train Recall: 66.04%, Train F1 Score: 68.99%
#
# EarlyStopping counter: 1 out of 30
# Epoch [24/100] with Learning Rate: [0.001]
# Loss: 0.5201
# Train Accuracy: 78.06% Train Precision: 72.86%, Train Recall: 66.26%, Train F1 Score: 69.14%
#
# ...
#
# Tracked Validation Score improved (0.5228 --> 0.5206). Saving model...
# Epoch [25/100] with Learning Rate: [0.001]
# Loss: 0.5207
# Train Accuracy: 78.15% Train Precision: 73.03%, Train Recall: 66.15%, Train F1 Score: 69.10%
#
# EarlyStopping counter: 1 out of 30
# Epoch [26/100] with Learning Rate: [0.001]
# Loss: 0.5191
# Train Accuracy: 78.19% Train Precision: 73.44%, Train Recall: 66.39%, Train F1 Score: 69.40%
#
# Tracked Validation Score improved (0.5206 --> 0.5191). Saving model...
# Epoch [27/100] with Learning Rate: [0.001]
# Loss: 0.5184
# Train Accuracy: 78.25% Train Precision: 73.38%, Train Recall: 66.44%, Train F1 Score: 69.46%
#
# Tracked Validation Score improved (0.5191 --> 0.5184). Saving model...
# Epoch [28/100] with Learning Rate: [0.001]
# Loss: 0.5181
# Train Accuracy: 78.23% Train Precision: 73.41%, Train Recall: 65.96%, Train F1 Score: 69.17%
#
# Tracked Validation Score improved (0.5184 --> 0.5181). Saving model...
# Epoch [29/100] with Learning Rate: [0.001]
# Loss: 0.5170
# Train Accuracy: 78.24% Train Precision: 73.63%, Train Recall: 66.58%, Train F1 Score: 69.62%
#
# Tracked Validation Score improved (0.5181 --> 0.5170). Saving model...
# Epoch [30/100] with Learning Rate: [0.001]
# Loss: 0.5168
# Train Accuracy: 78.21% Train Precision: 74.04%, Train Recall: 66.97%, Train F1 Score: 70.03%
#
# Tracked Validation Score improved (0.5170 --> 0.5168). Saving model...
# Epoch [31/100] with Learning Rate: [0.001]
# Loss: 0.5161
# Train Accuracy: 78.29% Train Precision: 74.52%, Train Recall: 67.12%, Train F1 Score: 70.32%
#
# Tracked Validation Score improved (0.5168 --> 0.5161). Saving model...
# Epoch [32/100] with Learning Rate: [0.001]
# Loss: 0.5160
# Train Accuracy: 78.32% Train Precision: 73.88%, Train Recall: 66.85%, Train F1 Score: 69.86%
#
# Tracked Validation Score improved (0.5161 --> 0.5160). Saving model...
# Epoch [33/100] with Learning Rate: [0.001]
# Loss: 0.5152
# Train Accuracy: 78.34% Train Precision: 73.71%, Train Recall: 66.54%, Train F1 Score: 69.66%
#
# Tracked Validation Score improved (0.5160 --> 0.5152). Saving model...
# Epoch [34/100] with Learning Rate: [0.001]
# Loss: 0.5141
# Train Accuracy: 78.37% Train Precision: 73.57%, Train Recall: 66.47%, Train F1 Score: 69.56%
#
# Tracked Validation Score improved (0.5152 --> 0.5141). Saving model...
# Epoch [35/100] with Learning Rate: [0.001]
# Loss: 0.5147
# Train Accuracy: 78.34% Train Precision: 73.94%, Train Recall: 66.33%, Train F1 Score: 69.58%
#
# EarlyStopping counter: 1 out of 30
# Epoch [36/100] with Learning Rate: [0.001]
# Loss: 0.5127
# Train Accuracy: 78.35% Train Precision: 74.17%, Train Recall: 67.13%, Train F1 Score: 70.16%
#
# Tracked Validation Score improved (0.5141 --> 0.5127). Saving model...
# Epoch [37/100] with Learning Rate: [0.001]
# Loss: 0.5126
# Train Accuracy: 78.49% Train Precision: 73.49%, Train Recall: 66.65%, Train F1 Score: 69.64%
#
# Tracked Validation Score improved (0.5127 --> 0.5126). Saving model...
# Epoch [38/100] with Learning Rate: [0.001]
# Loss: 0.5119
# Train Accuracy: 78.41% Train Precision: 73.36%, Train Recall: 66.51%, Train F1 Score: 69.48%
#
# Tracked Validation Score improved (0.5126 --> 0.5119). Saving model...
# Epoch [39/100] with Learning Rate: [0.001]
# Loss: 0.5115
# Train Accuracy: 78.36% Train Precision: 74.08%, Train Recall: 67.43%, Train F1 Score: 70.35%
#
# Tracked Validation Score improved (0.5119 --> 0.5115). Saving model...
# Epoch [40/100] with Learning Rate: [0.001]
# Loss: 0.5110
# Train Accuracy: 78.52% Train Precision: 73.75%, Train Recall: 66.65%, Train F1 Score: 69.72%
#
# Tracked Validation Score improved (0.5115 --> 0.5110). Saving model...
# Epoch [41/100] with Learning Rate: [0.001]
# Loss: 0.5104
# Train Accuracy: 78.41% Train Precision: 74.36%, Train Recall: 67.09%, Train F1 Score: 70.24%
#
# Tracked Validation Score improved (0.5110 --> 0.5104). Saving model...
# Epoch [42/100] with Learning Rate: [0.001]
# Loss: 0.5108
# Train Accuracy: 78.54% Train Precision: 74.64%, Train Recall: 67.58%, Train F1 Score: 70.62%
#
# EarlyStopping counter: 1 out of 30
# Epoch [43/100] with Learning Rate: [0.001]
# Loss: 0.5106
# Train Accuracy: 78.61% Train Precision: 74.07%, Train Recall: 67.31%, Train F1 Score: 70.23%
#
# EarlyStopping counter: 2 out of 30
# Epoch [44/100] with Learning Rate: [0.001]
# Loss: 0.5095
# Train Accuracy: 78.60% Train Precision: 73.72%, Train Recall: 66.68%, Train F1 Score: 69.67%
#
# Tracked Validation Score improved (0.5104 --> 0.5095). Saving model...
# Epoch [45/100] with Learning Rate: [0.001]
# Loss: 0.5083
# Train Accuracy: 78.58% Train Precision: 74.37%, Train Recall: 67.04%, Train F1 Score: 70.22%
#
# Tracked Validation Score improved (0.5095 --> 0.5083). Saving model...
# Epoch [46/100] with Learning Rate: [0.001]
# Loss: 0.5083
# Train Accuracy: 78.65% Train Precision: 74.41%, Train Recall: 67.47%, Train F1 Score: 70.49%
#
# Tracked Validation Score improved (0.5083 --> 0.5083). Saving model...
# Epoch [47/100] with Learning Rate: [0.001]
# Loss: 0.5082
# Train Accuracy: 78.56% Train Precision: 73.95%, Train Recall: 66.49%, Train F1 Score: 69.70%
#
# Tracked Validation Score improved (0.5083 --> 0.5082). Saving model...
# Epoch [48/100] with Learning Rate: [0.001]
# Loss: 0.5101
# Train Accuracy: 78.65% Train Precision: 74.16%, Train Recall: 67.29%, Train F1 Score: 70.28%
#
# EarlyStopping counter: 1 out of 30
# Epoch [49/100] with Learning Rate: [0.001]
# Loss: 0.5065
# Train Accuracy: 78.71% Train Precision: 74.18%, Train Recall: 67.27%, Train F1 Score: 70.26%
#
# Tracked Validation Score improved (0.5082 --> 0.5065). Saving model...
# Epoch [50/100] with Learning Rate: [0.001]
# Loss: 0.5070
# Train Accuracy: 78.68% Train Precision: 74.03%, Train Recall: 66.78%, Train F1 Score: 69.91%
#
# EarlyStopping counter: 1 out of 30
# Epoch [51/100] with Learning Rate: [0.001]
# Loss: 0.5066
# Train Accuracy: 78.66% Train Precision: 74.29%, Train Recall: 67.26%, Train F1 Score: 70.32%
#
# EarlyStopping counter: 2 out of 30
# Epoch [52/100] with Learning Rate: [0.001]
# Loss: 0.5061
# Train Accuracy: 78.75% Train Precision: 74.37%, Train Recall: 67.38%, Train F1 Score: 70.41%
#
# Tracked Validation Score improved (0.5065 --> 0.5061). Saving model...
# Epoch [53/100] with Learning Rate: [0.001]
# Loss: 0.5063
# Train Accuracy: 78.61% Train Precision: 74.43%, Train Recall: 67.78%, Train F1 Score: 70.69%
#
# EarlyStopping counter: 1 out of 30
# Epoch [54/100] with Learning Rate: [0.001]
# Loss: 0.5052
# Train Accuracy: 78.76% Train Precision: 74.99%, Train Recall: 68.14%, Train F1 Score: 71.11%
#
# Tracked Validation Score improved (0.5061 --> 0.5052). Saving model...
# Epoch [55/100] with Learning Rate: [0.001]
# Loss: 0.5054
# Train Accuracy: 78.72% Train Precision: 74.63%, Train Recall: 67.76%, Train F1 Score: 70.72%
#
# EarlyStopping counter: 1 out of 30
# Epoch [56/100] with Learning Rate: [0.001]
# Loss: 0.5047
# Train Accuracy: 78.73% Train Precision: 73.83%, Train Recall: 66.89%, Train F1 Score: 69.89%
#
# Tracked Validation Score improved (0.5052 --> 0.5047). Saving model...
# Epoch [57/100] with Learning Rate: [0.001]
# Loss: 0.5051
# Train Accuracy: 78.78% Train Precision: 74.51%, Train Recall: 67.74%, Train F1 Score: 70.69%
#
# EarlyStopping counter: 1 out of 30
# Epoch [58/100] with Learning Rate: [0.001]
# Loss: 0.5040
# Train Accuracy: 78.81% Train Precision: 74.11%, Train Recall: 67.39%, Train F1 Score: 70.32%
#
# Tracked Validation Score improved (0.5047 --> 0.5040). Saving model...
# Epoch [59/100] with Learning Rate: [0.001]
# Loss: 0.5042
# Train Accuracy: 78.83% Train Precision: 74.27%, Train Recall: 67.40%, Train F1 Score: 70.40%
#
# EarlyStopping counter: 1 out of 30
# Epoch [60/100] with Learning Rate: [0.001]
# Loss: 0.5037
# Train Accuracy: 78.87% Train Precision: 74.50%, Train Recall: 67.58%, Train F1 Score: 70.61%
#
# Tracked Validation Score improved (0.5040 --> 0.5037). Saving model...
# Epoch [61/100] with Learning Rate: [0.001]
# Loss: 0.5029
# Train Accuracy: 78.83% Train Precision: 74.50%, Train Recall: 67.69%, Train F1 Score: 70.66%
#
# Tracked Validation Score improved (0.5037 --> 0.5029). Saving model...
# Epoch [62/100] with Learning Rate: [0.001]
# Loss: 0.5035
# Train Accuracy: 78.91% Train Precision: 75.08%, Train Recall: 68.23%, Train F1 Score: 71.19%
#
# EarlyStopping counter: 1 out of 30
# Epoch [63/100] with Learning Rate: [0.001]
# Loss: 0.5030
# Train Accuracy: 78.82% Train Precision: 74.88%, Train Recall: 68.08%, Train F1 Score: 71.04%
#
# EarlyStopping counter: 2 out of 30
# Epoch [64/100] with Learning Rate: [0.001]
# Loss: 0.5026
# Train Accuracy: 78.90% Train Precision: 74.89%, Train Recall: 68.00%, Train F1 Score: 71.01%
#
# Tracked Validation Score improved (0.5029 --> 0.5026). Saving model...
# Epoch [65/100] with Learning Rate: [0.001]
# Loss: 0.5016
# Train Accuracy: 78.97% Train Precision: 74.49%, Train Recall: 67.58%, Train F1 Score: 70.59%
#
# Tracked Validation Score improved (0.5026 --> 0.5016). Saving model...
# Epoch [66/100] with Learning Rate: [0.001]
# Loss: 0.5014
# Train Accuracy: 78.93% Train Precision: 74.59%, Train Recall: 67.39%, Train F1 Score: 70.51%
#
# Tracked Validation Score improved (0.5016 --> 0.5014). Saving model...
# Epoch [67/100] with Learning Rate: [0.001]
# Loss: 0.5022
# Train Accuracy: 78.83% Train Precision: 74.05%, Train Recall: 67.94%, Train F1 Score: 70.63%
#
# EarlyStopping counter: 1 out of 30
# Epoch [68/100] with Learning Rate: [0.001]
# Loss: 0.5017
# Train Accuracy: 78.97% Train Precision: 75.13%, Train Recall: 67.91%, Train F1 Score: 71.03%
#
# EarlyStopping counter: 2 out of 30
# Epoch [69/100] with Learning Rate: [0.001]
# Loss: 0.5004
# Train Accuracy: 78.97% Train Precision: 75.32%, Train Recall: 68.49%, Train F1 Score: 71.49%
#
# Tracked Validation Score improved (0.5014 --> 0.5004). Saving model...
# Epoch [70/100] with Learning Rate: [0.001]
# Loss: 0.5010
# Train Accuracy: 79.00% Train Precision: 74.52%, Train Recall: 67.68%, Train F1 Score: 70.68%
#
# EarlyStopping counter: 1 out of 30
# Epoch [71/100] with Learning Rate: [0.001]
# Loss: 0.5011
# Train Accuracy: 78.92% Train Precision: 74.37%, Train Recall: 67.87%, Train F1 Score: 70.72%
#
# EarlyStopping counter: 2 out of 30
# Epoch [72/100] with Learning Rate: [0.001]
# Loss: 0.5006
# Train Accuracy: 78.96% Train Precision: 74.27%, Train Recall: 67.44%, Train F1 Score: 70.45%
#
# EarlyStopping counter: 3 out of 30
# Epoch [73/100] with Learning Rate: [0.001]
# Loss: 0.4998
# Train Accuracy: 78.98% Train Precision: 75.31%, Train Recall: 68.61%, Train F1 Score: 71.52%
#
# Tracked Validation Score improved (0.5004 --> 0.4998). Saving model...
# Epoch [74/100] with Learning Rate: [0.001]
# Loss: 0.5001
# Train Accuracy: 79.06% Train Precision: 75.14%, Train Recall: 68.25%, Train F1 Score: 71.26%
#
# EarlyStopping counter: 1 out of 30
# Epoch [75/100] with Learning Rate: [0.001]
# Loss: 0.5006
# Train Accuracy: 78.98% Train Precision: 74.95%, Train Recall: 67.75%, Train F1 Score: 70.87%
#
# EarlyStopping counter: 2 out of 30
# Epoch [76/100] with Learning Rate: [0.001]
# Loss: 0.5000
# Train Accuracy: 79.05% Train Precision: 74.76%, Train Recall: 68.30%, Train F1 Score: 71.13%
#
# EarlyStopping counter: 3 out of 30
# Epoch [77/100] with Learning Rate: [0.001]
# Loss: 0.4992
# Train Accuracy: 79.00% Train Precision: 74.30%, Train Recall: 67.46%, Train F1 Score: 70.46%
#
# Tracked Validation Score improved (0.4998 --> 0.4992). Saving model...
# Epoch [78/100] with Learning Rate: [0.001]
# Loss: 0.4991
# Train Accuracy: 79.09% Train Precision: 75.02%, Train Recall: 68.23%, Train F1 Score: 71.20%
#
# Tracked Validation Score improved (0.4992 --> 0.4991). Saving model...
# Epoch [79/100] with Learning Rate: [0.001]
# Loss: 0.4991
# Train Accuracy: 79.05% Train Precision: 74.36%, Train Recall: 67.77%, Train F1 Score: 70.65%
#
# EarlyStopping counter: 1 out of 30
# Epoch [80/100] with Learning Rate: [0.001]
# Loss: 0.4990
# Train Accuracy: 79.05% Train Precision: 74.16%, Train Recall: 67.47%, Train F1 Score: 70.41%
#
# Tracked Validation Score improved (0.4991 --> 0.4990). Saving model...
# Epoch [81/100] with Learning Rate: [0.001]
# Loss: 0.4995
# Train Accuracy: 79.05% Train Precision: 74.56%, Train Recall: 67.42%, Train F1 Score: 70.51%
#
# EarlyStopping counter: 1 out of 30
# Epoch [82/100] with Learning Rate: [0.001]
# Loss: 0.4982
# Train Accuracy: 79.09% Train Precision: 74.66%, Train Recall: 67.79%, Train F1 Score: 70.81%
#
# Tracked Validation Score improved (0.4990 --> 0.4982). Saving model...
# Epoch [83/100] with Learning Rate: [0.001]
# Loss: 0.4986
# Train Accuracy: 79.09% Train Precision: 74.24%, Train Recall: 67.87%, Train F1 Score: 70.70%
#
# EarlyStopping counter: 1 out of 30
# Epoch [84/100] with Learning Rate: [0.001]
# Loss: 0.4975
# Train Accuracy: 79.16% Train Precision: 75.09%, Train Recall: 68.19%, Train F1 Score: 71.19%
#
# Tracked Validation Score improved (0.4982 --> 0.4975). Saving model...
# Epoch [85/100] with Learning Rate: [0.001]
# Loss: 0.4986
# Train Accuracy: 79.02% Train Precision: 74.71%, Train Recall: 68.15%, Train F1 Score: 71.02%
#
# EarlyStopping counter: 1 out of 30
# Epoch [86/100] with Learning Rate: [0.001]
# Loss: 0.4995
# Train Accuracy: 79.13% Train Precision: 74.91%, Train Recall: 68.10%, Train F1 Score: 71.01%
#
# EarlyStopping counter: 2 out of 30
# Epoch [87/100] with Learning Rate: [0.001]
# Loss: 0.4975
# Train Accuracy: 79.09% Train Precision: 74.68%, Train Recall: 67.76%, Train F1 Score: 70.80%
#
# Tracked Validation Score improved (0.4975 --> 0.4975). Saving model...
# Epoch [88/100] with Learning Rate: [0.001]
# Loss: 0.4973
# Train Accuracy: 79.08% Train Precision: 74.50%, Train Recall: 67.56%, Train F1 Score: 70.59%
#
# Tracked Validation Score improved (0.4975 --> 0.4973). Saving model...
# Epoch [89/100] with Learning Rate: [0.001]
# Loss: 0.4979
# Train Accuracy: 79.15% Train Precision: 75.62%, Train Recall: 68.74%, Train F1 Score: 71.76%
#
# EarlyStopping counter: 1 out of 30
# Epoch [90/100] with Learning Rate: [0.001]
# Loss: 0.4967
# Train Accuracy: 79.20% Train Precision: 74.92%, Train Recall: 68.12%, Train F1 Score: 71.10%
#
# Tracked Validation Score improved (0.4973 --> 0.4967). Saving model...
# Epoch [91/100] with Learning Rate: [0.001]
# Loss: 0.4967
# Train Accuracy: 79.14% Train Precision: 74.40%, Train Recall: 67.62%, Train F1 Score: 70.57%
#
# Tracked Validation Score improved (0.4967 --> 0.4967). Saving model...
# Epoch [92/100] with Learning Rate: [0.001]
# Loss: 0.4964
# Train Accuracy: 79.10% Train Precision: 74.32%, Train Recall: 67.78%, Train F1 Score: 70.63%
#
# Tracked Validation Score improved (0.4967 --> 0.4964). Saving model...
# Epoch [93/100] with Learning Rate: [0.001]
# Loss: 0.4966
# Train Accuracy: 79.20% Train Precision: 74.82%, Train Recall: 68.30%, Train F1 Score: 71.18%
#
# EarlyStopping counter: 1 out of 30
# Epoch [94/100] with Learning Rate: [0.001]
# Loss: 0.4970
# Train Accuracy: 79.18% Train Precision: 74.68%, Train Recall: 68.22%, Train F1 Score: 71.06%
#
# EarlyStopping counter: 2 out of 30
# Epoch [95/100] with Learning Rate: [0.001]
# Loss: 0.4959
# Train Accuracy: 79.16% Train Precision: 75.46%, Train Recall: 68.42%, Train F1 Score: 71.50%
#
# Tracked Validation Score improved (0.4964 --> 0.4959). Saving model...
# Epoch [96/100] with Learning Rate: [0.001]
# Loss: 0.4961
# Train Accuracy: 79.15% Train Precision: 74.94%, Train Recall: 68.33%, Train F1 Score: 71.23%
#
# EarlyStopping counter: 1 out of 30
# Epoch [97/100] with Learning Rate: [0.001]
# Loss: 0.4957
# Train Accuracy: 79.22% Train Precision: 75.03%, Train Recall: 67.83%, Train F1 Score: 70.97%
#
# Tracked Validation Score improved (0.4959 --> 0.4957). Saving model...
# Epoch [98/100] with Learning Rate: [0.001]
# Loss: 0.4954
# Train Accuracy: 79.14% Train Precision: 74.33%, Train Recall: 67.87%, Train F1 Score: 70.70%
#
# Tracked Validation Score improved (0.4957 --> 0.4954). Saving model...
# Epoch [99/100] with Learning Rate: [0.001]
# Loss: 0.4957
# Train Accuracy: 79.22% Train Precision: 74.74%, Train Recall: 68.43%, Train F1 Score: 71.19%
#
# EarlyStopping counter: 1 out of 30
# Epoch [100/100] with Learning Rate: [0.001]
# Loss: 0.4947
# Train Accuracy: 79.24% Train Precision: 74.50%, Train Recall: 67.41%, Train F1 Score: 70.50%
#
# Tracked Validation Score improved (0.4954 --> 0.4947). Saving model...
#
# Fold 10 Performance:
#
# Best Train Loss: 0.4947
# Best Train Accuracy: 79.24%
# Best Train Precision: 74.50%
# Best Train Recall: 67.41%
# Best Train F1 Score: 70.50%

# %%
# Aggregate metrics across all folds
avg_train_loss = np.mean(fold_metrics["train_loss"])
avg_train_accuracy = np.mean(fold_metrics["train_accuracy"])
avg_train_precision = np.mean(fold_metrics["train_precision"])
avg_train_recall = np.mean(fold_metrics["train_recall"])
avg_train_f1 = np.mean(fold_metrics["train_f1"])

print(f"Average Train Loss: {avg_train_loss:.4f}")
print(f"Average Train Accuracy: {avg_train_accuracy:.2%}")
print(f"Average Train Precision: {avg_train_precision:.2%}")
print(f"Average Train Recall: {avg_train_recall:.2%}")
print(f"Average Train F1 Score: {avg_train_f1:.2%}")

# Print the Best performance across all folds
best_fold = np.argmin(fold_performance["train_loss"])
best_train_loss = fold_performance["train_loss"][best_fold]
best_train_accuracy = fold_performance["train_accuracy"][best_fold]
best_train_precision = fold_performance["train_precision"][best_fold]
best_train_recall = fold_performance["train_recall"][best_fold]
best_train_f1 = fold_performance["train_f1"][best_fold]

print(f"Best Fold: {best_fold + 1}")
print(f"Best Train Loss: {best_train_loss:.4f}")
print(f"Best Train Accuracy: {best_train_accuracy:.2%}")
print(f"Best Train Precision: {best_train_precision:.2%}")
print(f"Best Train Recall: {best_train_recall:.2%}")
print(f"Best Train F1 Score: {best_train_f1:.2%}")
# Out:
# Average Train Loss: 0.5124
# Average Train Accuracy: 78.50%
# Average Train Precision: 73.69%
# Average Train Recall: 66.68%
# Average Train F1 Score: 69.72%
# Best Fold: 3
# Best Train Loss: 0.4923
# Best Train Accuracy: 79.34%
# Best Train Precision: 74.66%
# Best Train Recall: 67.57%
# Best Train F1 Score: 70.66%

# %%
# Evaluate the model on the test set
model.eval()
test_loss = 0
y_test_true = []
y_test_pred = []
model.load_state_dict(torch.load(f'checkpoints/fies_ann_checkpoint_fold{best_fold+1}.pth'))
print(f"Loading model from checkpoint: checkpoints/fies_ann_checkpoint_fold{best_fold+1}.pth")
with torch.no_grad():
    for batch in test_dataloader:
        inputs, labels = batch
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        test_loss += loss.item()

        # Get predicted class (index of the max logit)
        preds = torch.argmax(outputs, dim=1)

        y_test_true.extend(labels.cpu().numpy())
        y_test_pred.extend(preds.cpu().numpy())

test_loss /= len(test_dataloader)
test_accuracy = accuracy_score(y_test_true, y_test_pred)
test_precision = precision_score(y_test_true, y_test_pred, average='macro')
test_recall = recall_score(y_test_true, y_test_pred, average='macro')
test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_accuracy:.2%}')
print(f'Test Precision: {test_precision:.2%}')
print(f'Test Recall: {test_recall:.2%}')
print(f'Test F1 Score: {test_f1:.2%}')
# Out:
# Loading model from checkpoint: checkpoints/fies_ann_checkpoint_fold3.pth
# /var/folders/mp/c7pgmq8j0472f05vnx5h16000000gn/T/ipykernel_80619/3520914535.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'checkpoints/fies_ann_checkpoint_fold{best_fold+1}.pth'))
# Test Loss: 0.5875
# Test Accuracy: 76.61%
# Test Precision: 70.28%
# Test Recall: 63.83%
# Test F1 Score: 66.63%

# %%
# Confusion Matrix
cm = confusion_matrix(y_test_true, y_test_pred)
cm_df = pd.DataFrame(cm, index=dataset['income_group'].unique(), columns=dataset['income_group'].unique())
print(cm_df)
# Out:
#                              Middle Middle Class  Lower Middle Income  \
# Middle Middle Class                        16993                 1707
# Lower Middle Income                         3013                 9707
# Low Income (but not poor)                     37                 1280
# Upper Middle Income                         1852                   10
# Upper Income (but not rich)                    2                    0
# Poor                                           1                    1
# Rich                                           1                   40
#
#                              Low Income (but not poor)  Upper Middle Income  \
# Middle Middle Class                                 14                 1857
# Lower Middle Income                                677                   25
# Low Income (but not poor)                         2737                    0
# Upper Middle Income                                  0                 7267
# Upper Income (but not rich)                          2                    0
# Poor                                                16                    0
# Rich                                               435                    0
#
#                              Upper Income (but not rich)  Poor  Rich
# Middle Middle Class                                    0     0     1
# Lower Middle Income                                    1     0    14
# Low Income (but not poor)                              1     4   258
# Upper Middle Income                                    0     0     0
# Upper Income (but not rich)                           41    22    15
# Poor                                                  20   107   106
# Rich                                                   0    45   672

# %%
# Summary of the model
from IPython.display import display, HTML

html_table = f"""
<table border="1" style="border-collapse: collapse; width: 100%;">
    <thead>
        <tr>
            <th>Train Loss</th>
            <th>Train Accuracy</th>
            <th>Train Precision</th>
            <th>Train Recall</th>
            <th>Train F1 Score</th>
            <th>Test Loss</th>
            <th>Test Accuracy</th>
            <th>Test Precision</th>
            <th>Test Recall</th>
            <th>Test F1 Score</th>
        </tr>
    </thead>

    <tbody>
        <tr>
            <td>{best_train_loss:.4f}</td>
            <td>{best_train_accuracy:.2%}</td>
            <td>{best_train_precision:.2%}</td>
            <td>{best_train_recall:.2%}</td>
            <td>{best_train_f1:.2%}</td>
            <td>{test_loss:.4f}</td>
            <td>{test_accuracy:.2%}</td>
            <td>{test_precision:.2%}</td>
            <td>{test_recall:.2%}</td>
            <td>{test_f1:.2%}</td>
        </tr>
    </tbody>
</table>
"""

display(HTML(html_table))
# Out:
# <table border="1" style="border-collapse: collapse; width: 100%;">
#     <thead>
#         <tr>
#             <th>Train Loss</th>
#             <th>Train Accuracy</th>
#             <th>Train Precision</th>
#             <th>Train Recall</th>
#             <th>Train F1 Score</th>
#             <th>Test Loss</th>
#             <th>Test Accuracy</th>
#             <th>Test Precision</th>
#             <th>Test Recall</th>
#             <th>Test F1 Score</th>
#         </tr>
#     </thead>
#
#     <tbody>
#         <tr>
#             <td>0.4923</td>
#             <td>79.34%</td>
#             <td>74.66%</td>
#             <td>67.57%</td>
#             <td>70.66%</td>
#             <td>0.5875</td>
#             <td>76.61%</td>
#             <td>70.28%</td>
#             <td>63.83%</td>
#             <td>66.63%</td>
#         </tr>
#     </tbody>
# </table>
